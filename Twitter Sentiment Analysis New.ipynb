# %% [markdown]
# # Importing the Required Libraries

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import string
from nltk import pos_tag
import warnings
warnings.filterwarnings("ignore")
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Preparing Training Data

# %% [markdown]
# # Importing Training Data

# %%
df = pd.read_csv('twitter train.csv')

# %%
df = df[['text', 'airline_sentiment']]

# %%
df
# Out:
#                                                     text airline_sentiment
# 0      @SouthwestAir I am scheduled for the morning, ...          negative
# 1      @SouthwestAir seeing your workers time in and ...          positive
# 2      @united Flew ORD to Miami and back and  had gr...          positive
# 3         @SouthwestAir @dultch97 that's horse radish 😤🐴          negative
# 4      @united so our flight into ORD was delayed bec...          negative
# ...                                                  ...               ...
# 10975                            @AmericanAir followback           neutral
# 10976  @united thanks for the help. Wish the phone re...          positive
# 10977  @usairways the. Worst. Ever. #dca #customerser...          negative
# 10978  @nrhodes85: look! Another apology. DO NOT FLY ...          negative
# 10979  @united you are by far the worst airline. 4 pl...          negative
#
# [10980 rows x 2 columns]

# %%
features = df.iloc[:, :-1]
labels = df.iloc[:, -1]

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size=0.30, random_state=45)

# %%
print(train_features.describe())
print(train_labels.describe())
print(test_features.describe())
print(test_labels.describe())
# Out:
#                   text
# count             7686
# unique            7617
# top     @united thanks
# freq                 5
# count         7686
# unique           3
# top       negative
# freq          4800
# Name: airline_sentiment, dtype: object
#                        text
# count                  3294
# unique                 3281
# top     @JetBlue thank you!
# freq                      3
# count         3294
# unique           3
# top       negative
# freq          2051
# Name: airline_sentiment, dtype: object

# %%
training_data = pd.concat([train_features, train_labels], axis=1)
training_data = training_data.values
training_data
# Out:
# array([["@JetBlue  I shouldn't have to find them, they should tell us. I've flown Jet Blue since your first month. The experience isn't what it was.",
#         'negative'],
#        ['@SouthwestAir is there a resource to check delays/Cancelled Flightlations out of Love Field? Flying out tomorrow am and stressed about weather! ❄️',
#         'neutral'],
#        ["@SouthwestAir I figured the streaming wouldn't work per the TOS but just the @NASCAR site is taking longer than 5 minutes to load",
#         'negative'],
#        ...,
#        ['@SouthwestAir has some of the best airfare prices! Gotta LUV them :)',
#         'positive'],
#        ['@SouthwestAir even with the 50$ voucher for picking up my bag',
#         'negative'],
#        ['@united sat at airport for 5 hrs still sitting at gate..  Sigh',
#         'negative']], dtype=object)

# %% [markdown]
# # Splitting the Tweet text into words using NLTK

# %%
tweets_train = []
for i in range(len(training_data)):
    tweets_train.append([word_tokenize(training_data[i][0]), training_data[i][1]]) 
tweets_train
# Out:
# [[['@',
#    'JetBlue',
#    'I',
#    'should',
#    "n't",
#    'have',
#    'to',
#    'find',
#    'them',
#    ',',
#    'they',
#    'should',
#    'tell',
#    'us',
#    '.',
#    'I',
#    "'ve",
#    'flown',
#    'Jet',
#    'Blue',
#    'since',
#    'your',
#    'first',
#    'month',
#    '.',
#    'The',
#    'experience',
#    'is',
#    "n't",
#    'what',
#    'it',
#    'was',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'is',
#    'there',
#    'a',
#    'resource',
#    'to',
#    'check',
#    'delays/Cancelled',
#    'Flightlations',
#    'out',
#    'of',
#    'Love',
#    'Field',
#    '?',
#    'Flying',
#    'out',
#    'tomorrow',
#    'am',
#    'and',
#    'stressed',
#    'about',
#    'weather',
#    '!',
#    '❄️'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    'I',
#    'figured',
#    'the',
#    'streaming',
#    'would',
#    "n't",
#    'work',
#    'per',
#    'the',
#    'TOS',
#    'but',
#    'just',
#    'the',
#    '@',
#    'NASCAR',
#    'site',
#    'is',
#    'taking',
#    'longer',
#    'than',
#    '5',
#    'minutes',
#    'to',
#    'load'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'We',
#    'all',
#    'did',
#    '!',
#    'Skipper',
#    "'s",
#    'walk-around',
#    'too',
#    ':',
#    '('],
#   'negative'],
#  [['@',
#    'USAirways',
#    '@',
#    'PHLAirport',
#    'Cancelled',
#    'Flighted',
#    'flight',
#    'due',
#    'to',
#    'weather',
#    'no',
#    'problem',
#    ',',
#    'but',
#    'wait',
#    'for',
#    'luggage',
#    'for',
#    '4',
#    'hours',
#    '?',
#    '?',
#    'IT',
#    'MUST',
#    'BE',
#    'DELIVERED',
#    '!',
#    '!'],
#   'negative'],
#  [['@',
#    'united',
#    'Want',
#    'to',
#    'book',
#    'a',
#    'multi-city',
#    'fare',
#    '.',
#    'Have',
#    'miles',
#    'for',
#    '1of',
#    '2',
#    'flights',
#    '.',
#    'An',
#    'option',
#    'to',
#    'pay',
#    'for',
#    '1st',
#    'flight',
#    'with',
#    'miles',
#    '+2nd',
#    'with',
#    'UMP',
#    'Visa',
#    '?',
#    'Thanks',
#    '!'],
#   'neutral'],
#  [['@', 'united', 'maybe', 'on', 'my', 'return', 'trip', '👍'], 'positive'],
#  [['@',
#    'USAirways',
#    'over',
#    '4',
#    'weeks',
#    'since',
#    'you',
#    'took',
#    'our',
#    'money',
#    'and',
#    'left',
#    'us',
#    'stranded',
#    '9',
#    'hours',
#    'from',
#    'home',
#    '.',
#    'Had',
#    'to',
#    'rent',
#    'a',
#    'car',
#    'and',
#    'you',
#    'still',
#    'have',
#    'not',
#    'helped',
#    'us'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'Just',
#    'to',
#    'follow',
#    'up',
#    'here',
#    'is',
#    'my',
#    'experience',
#    ':',
#    'http',
#    ':',
#    '//t.co/WJIiGZtiwg'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'Your',
#    'crew',
#    'on',
#    '4028',
#    'tonight',
#    'was',
#    'outstanding',
#    '.',
#    'God',
#    'bless',
#    'them',
#    'and',
#    'the',
#    'medically',
#    'trained',
#    'passengers',
#    'on',
#    'board',
#    '.'],
#   'positive'],
#  [['“',
#    '@',
#    'JetBlue',
#    ':',
#    'Our',
#    'fleet',
#    "'s",
#    'on',
#    'fleek',
#    '.',
#    'http',
#    ':',
#    '//t.co/g97HAbyeP5',
#    '”',
#    'SMH'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'record',
#    'locator',
#    'oaaret',
#    'got',
#    'email',
#    'we',
#    'could',
#    "n't",
#    'be',
#    'rebooked',
#    'but',
#    'got',
#    'no',
#    'notification',
#    'flight',
#    'was',
#    'Cancelled',
#    'Flightled'],
#   'negative'],
#  [['@',
#    'USAirways',
#    '@',
#    'Jack_Kairys',
#    'your',
#    'site',
#    'clearly',
#    'explains',
#    'we',
#    'are',
#    'allowed',
#    'a',
#    'carry',
#    'on',
#    '.',
#    'This',
#    'was',
#    'allowed',
#    'at',
#    'PIT',
#    'but',
#    'not',
#    'BOS',
#    '.',
#    'How',
#    'does',
#    'that',
#    'make',
#    'sense',
#    '?'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'been',
#    'on',
#    'hold',
#    'for',
#    '2',
#    '1/2',
#    'hrs',
#    '.',
#    'Ca',
#    "n't",
#    'get',
#    '2',
#    'airport',
#    '4',
#    'flight',
#    'icy',
#    'country',
#    'backroads',
#    '!',
#    'Help',
#    'pls',
#    '?',
#    'Can',
#    'a',
#    'human',
#    'answer',
#    '?',
#    '#',
#    'BNA'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'US',
#    'airways',
#    'csr',
#    'at',
#    'Phoenix',
#    'airport',
#    'fixed',
#    'the',
#    'problem'],
#   'neutral'],
#  [['Decisions',
#    'Decisions',
#    '@',
#    'MandarinJourney',
#    '@',
#    'united',
#    ':',
#    'We',
#    "'d",
#    'love',
#    'for',
#    'you',
#    'to',
#    'try',
#    'our',
#    'service',
#    '.',
#    'We',
#    'offer',
#    'status',
#    'match',
#    'too',
#    '.',
#    'http',
#    ':',
#    '//t.co/xbQqqbRgVF',
#    '^KP',
#    '”'],
#   'neutral'],
#  [['@',
#    'USAirways',
#    'after',
#    '2',
#    'hrs',
#    'of',
#    'trying',
#    'to',
#    'reach',
#    'real',
#    'human',
#    ',',
#    'finally',
#    'did',
#    'and',
#    'been',
#    'on',
#    'hold',
#    'for',
#    '1:36',
#    'hrs',
#    'for',
#    'out',
#    'of',
#    'synch',
#    'reservation',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    'now',
#    '1558',
#    'from',
#    'IAH',
#    'to',
#    'EWR',
#    'has',
#    'broken',
#    'entertainment',
#    'system',
#    'and',
#    'no',
#    'WiFi',
#    'despite',
#    'info',
#    'on',
#    'app',
#    ':',
#    'http',
#    ':',
#    '//t.co/FY6f9rZB9k'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'flying',
#    'Southwest',
#    'for',
#    'the',
#    'first',
#    'time',
#    'to',
#    'LGA',
#    'with',
#    'a',
#    'layover',
#    'in',
#    'Atlanta',
#    '!'],
#   'neutral'],
#  [['@',
#    'JetBlue',
#    'loving',
#    'the',
#    'free',
#    '#',
#    'wifi',
#    'and',
#    '#',
#    'legroom',
#    '✈️',
#    '#',
#    'SeattleBound'],
#   'positive'],
#  [['@',
#    'united',
#    'you',
#    'guys',
#    'are',
#    'horrible',
#    '!',
#    'First',
#    'we',
#    'get',
#    'stuck',
#    'in',
#    'the',
#    'snow',
#    'for',
#    'a',
#    'hr',
#    'in',
#    'ewr',
#    'now',
#    'sitting',
#    'in',
#    'cmh',
#    'saying',
#    'it',
#    'could',
#    'be',
#    '30min',
#    'for',
#    'a',
#    'gate'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'in',
#    'my',
#    '30',
#    'years',
#    'of',
#    'flying',
#    'I',
#    'have',
#    'never',
#    'been',
#    'so',
#    'pissed',
#    'off',
#    '.',
#    'To',
#    'many',
#    'incidents',
#    'for',
#    'just',
#    'one',
#    'flight',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'has',
#    'the',
#    'WORST',
#    'customer',
#    'service',
#    'and',
#    'their',
#    'flights',
#    'are',
#    'always',
#    'delayed'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'thank',
#    'you',
#    'Mr',
#    'Parker',
#    'for',
#    'screwing',
#    'over',
#    'chairman',
#    'preferred',
#    'when',
#    'we',
#    'fly',
#    'AA',
#    '.',
#    'No',
#    '#',
#    'firstclass',
#    'option',
#    'and',
#    'treated',
#    'like',
#    'crap',
#    'by',
#    'staff'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'at',
#    'what',
#    'point',
#    'do',
#    'u',
#    'Cancelled',
#    'Flight',
#    'flights',
#    'to',
#    'DCA-',
#    'other',
#    'airlines',
#    'have',
#    'already',
#    'Cancelled',
#    'Flightled'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'I',
#    "'ve",
#    'been',
#    'tryin',
#    'to',
#    'use',
#    'my',
#    'voucher',
#    'to',
#    'book',
#    'a',
#    'flight',
#    'the',
#    'last',
#    '2days',
#    '.',
#    'Lines',
#    'are',
#    'busy',
#    '.',
#    'Plse',
#    'help',
#    'me',
#    '?',
#    'The',
#    'flight',
#    'may',
#    'go',
#    'up',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    'I',
#    "'m",
#    'on',
#    'hold',
#    'for',
#    'the',
#    '4th',
#    'time',
#    'waiting',
#    'for',
#    'you',
#    'to',
#    'resolve',
#    'and',
#    'issue',
#    'with',
#    'a',
#    'flight',
#    'for',
#    'my',
#    '6-year-old',
#    'son',
#    '.',
#    '#',
#    'terribleservice',
#    '#',
#    'NoService'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    '1st',
#    'leg',
#    'of',
#    'my',
#    'flight',
#    '2',
#    'nyc',
#    'tomorrow',
#    'has',
#    'been',
#    'Cancelled',
#    'Flightled',
#    '.',
#    'if',
#    'you',
#    'make',
#    'me',
#    'hold',
#    'for',
#    '2hrs',
#    'i',
#    'may',
#    'miss',
#    'my',
#    'only',
#    'chance',
#    'back',
#    'home',
#    '!'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'Thank',
#    'you',
#    'guys',
#    '!',
#    'Brilliant',
#    'customer',
#    'service'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'US',
#    '728',
#    'then',
#    'lost',
#    'ground',
#    'power',
#    'three',
#    'different',
#    'times',
#    '.',
#    'Not',
#    'only',
#    'grounded',
#    'endlessly',
#    ';',
#    'now',
#    'without',
#    'air',
#    ',',
#    'lights',
#    ',',
#    'entertainment',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    '...',
#    'still',
#    'waiting',
#    'for',
#    'a',
#    'call',
#    'back',
#    '....',
#    'attempt',
#    '#',
#    '9',
#    'and',
#    'hour',
#    '#',
#    '13',
#    '...',
#    'ca',
#    "n't",
#    'put',
#    'a',
#    'hold',
#    'on',
#    'an',
#    'online',
#    'tix',
#    ',',
#    'we',
#    'are',
#    'within',
#    'seven',
#    'day',
#    'window',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'Not',
#    'your',
#    'finest',
#    'moment',
#    'in',
#    'Boston',
#    'right',
#    'now',
#    '!'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'Yes',
#    ',',
#    'but',
#    'I',
#    'like',
#    'need',
#    'my',
#    'luggage',
#    'before',
#    'tomorrow',
#    'morning'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'I',
#    "'m",
#    'a',
#    'trying',
#    '!',
#    'But',
#    'I',
#    "'m",
#    'tired',
#    'and',
#    'getting',
#    'grumpy',
#    '!'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'what',
#    "'s",
#    'the',
#    'deal',
#    'with',
#    'the',
#    'flight',
#    'computer',
#    'network',
#    '?'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'been',
#    'on',
#    'hold',
#    'for',
#    '&',
#    'gt',
#    ';',
#    '30',
#    'minutes',
#    'about',
#    'my',
#    'Cancelled',
#    'Flightled',
#    'flight',
#    '.',
#    'Still',
#    'not',
#    'talked',
#    'to',
#    'anyone',
#    'and',
#    'flight',
#    'is',
#    'soon',
#    '.',
#    'What',
#    'gives',
#    '?'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'Your',
#    'response',
#    'could',
#    'have',
#    'made',
#    'all',
#    'the',
#    'difference',
#    '.',
#    'It',
#    'could',
#    'have',
#    'made',
#    'the',
#    'situation',
#    'better',
#    '.',
#    'NO',
#    'TRUST',
#    '...',
#    'GET',
#    'LOST',
#    'like',
#    'my',
#    'bag',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'Thanks',
#    '!',
#    'Sent',
#    'a',
#    'DM',
#    'to',
#    'you',
#    '.',
#    'Let',
#    'me',
#    'know',
#    'if',
#    'oyu',
#    'need',
#    'any',
#    'additional',
#    'information',
#    '.'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'thanks',
#    'for',
#    'helping',
#    'with',
#    '#',
#    'reFlight',
#    'Booking',
#    'Problems',
#    '#',
#    'Cancelled',
#    'Flightedflight',
#    'Yvonne',
#    'Anthony',
#    '.',
#    'You',
#    'will',
#    'help',
#    'us',
#    'get',
#    'to',
#    'Tel',
#    'Aviv',
#    'on',
#    'time',
#    '.',
#    '#',
#    'HappyFriday'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'congrats',
#    'on',
#    'treating',
#    'your',
#    'customers',
#    'the',
#    'worst',
#    'way',
#    'possible',
#    '.',
#    'I',
#    'know',
#    'plenty',
#    'of',
#    'other',
#    'ppl',
#    'who',
#    'have',
#    'had',
#    'horrible',
#    'experience',
#    'w',
#    'you',
#    'too'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'Not',
#    'true',
#    '!',
#    '!',
#    'Stop',
#    'making',
#    'excuses',
#    '!',
#    'You',
#    'either',
#    'overbook',
#    'or',
#    'have',
#    'crappy',
#    'planes',
#    '!'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'no',
#    'apologies',
#    'required',
#    '.',
#    'I',
#    'made',
#    'it',
#    'home',
#    'safe',
#    'thanks',
#    'to',
#    'you',
#    '!',
#    'Kudos',
#    'to',
#    'AA',
#    '!'],
#   'positive'],
#  [['@', 'SouthwestAir', 'Gracias', '...', 'appreciate', 'that', '!'],
#   'positive'],
#  [['@',
#    'united',
#    'system',
#    'failure',
#    'again',
#    '=',
#    'bad',
#    'trend',
#    '.',
#    'Software',
#    'projects',
#    'are',
#    'like',
#    'flying',
#    'an',
#    'airplane',
#    ';',
#    'there',
#    "'s",
#    'no',
#    'such',
#    'thing',
#    'as',
#    'an',
#    'emergency',
#    'takeoff',
#    '.'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'ticket',
#    'issued',
#    'whilst',
#    'delivering',
#    'your',
#    'customers',
#    '.'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'Just',
#    'looking',
#    'to',
#    'arrange',
#    'for',
#    'a',
#    'nice',
#    'flight',
#    'from',
#    'SEA',
#    'to',
#    'LA-ish',
#    'and',
#    'comparing',
#    'the',
#    'cost',
#    'to',
#    'something',
#    'more',
#    'direct',
#    'from',
#    'YVR',
#    '.'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'should',
#    'be',
#    'seeing',
#    'this',
#    'sunset',
#    'from',
#    'St.',
#    'John',
#    'usvi',
#    'not',
#    'philly',
#    '!',
#    '!',
#    'http',
#    ':',
#    '//t.co/DnDOepquKz'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'To',
#    'announce',
#    'DURING',
#    'BOARDING',
#    'that',
#    'you',
#    'chose',
#    'to',
#    'limit',
#    'catering',
#    'to',
#    'the',
#    'point',
#    'that',
#    'you',
#    'WILL',
#    'run',
#    'out',
#    'shows',
#    'a',
#    'lack',
#    'of',
#    'planning',
#    ',',
#    'IMO',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    'what',
#    'happened',
#    'to',
#    'flight',
#    'status',
#    'map',
#    '?',
#    'It',
#    'was',
#    'so',
#    'cool',
#    '..'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'I',
#    'bought',
#    'a',
#    'plane',
#    'ticket',
#    '2',
#    'months',
#    'ago',
#    'and',
#    'still',
#    'have',
#    "n't",
#    'received',
#    'my',
#    'flight',
#    'info',
#    'and',
#    'ticket',
#    'in',
#    'my',
#    'email',
#    'when',
#    'it',
#    'will',
#    'come',
#    '?'],
#   'negative'],
#  [['@',
#    'united',
#    '@',
#    'MaxAbrahms',
#    '*',
#    'if',
#    '*',
#    'he',
#    'needs',
#    'assistance',
#    '?',
#    'Do',
#    'you',
#    'expect',
#    'him',
#    'to',
#    'go',
#    'on',
#    'a',
#    'Scooby',
#    'Doo',
#    'tour',
#    'of',
#    'terminals',
#    'until',
#    'he',
#    'finds',
#    'his',
#    'stuff',
#    '?'],
#   'negative'],
#  [['@',
#    'united',
#    'why',
#    'do',
#    "n't",
#    'you',
#    'de-ice',
#    'while',
#    'the',
#    'plane',
#    'sits',
#    'there',
#    'with',
#    'no',
#    'one',
#    'in',
#    'it',
#    'for',
#    '2',
#    'hours',
#    '?',
#    '?',
#    'Or',
#    'we',
#    'could',
#    'just',
#    'delay',
#    ':',
#    '/'],
#   'negative'],
#  [['@',
#    'VirginAmerica',
#    'Why',
#    'is',
#    'the',
#    'site',
#    'down',
#    '?',
#    'When',
#    'will',
#    'it',
#    'be',
#    'back',
#    'up',
#    '?'],
#   'negative'],
#  [['@',
#    'united',
#    'can',
#    'you',
#    'help',
#    'me',
#    'add',
#    'my',
#    'KTN',
#    'to',
#    'this',
#    'reservation',
#    'PLZ',
#    '?'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'I',
#    'thought',
#    'all',
#    'those',
#    'planes',
#    'were',
#    'retired',
#    '?',
#    '#',
#    'MD80'],
#   'neutral'],
#  [['@',
#    'united',
#    'we',
#    'would',
#    '...',
#    'how',
#    'do',
#    'I',
#    'contact',
#    'you',
#    'to',
#    'discuss',
#    '?',
#    'A',
#    'few',
#    'poor',
#    'experiences',
#    'with',
#    'customer',
#    'service',
#    'but',
#    'would',
#    'give',
#    'it',
#    'a',
#    'shot',
#    '!'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'also',
#    '.',
#    'Emergency',
#    'exit',
#    'seats',
#    '.',
#    '6',
#    "'",
#    '2',
#    "''",
#    'and',
#    'that',
#    "'s",
#    'a',
#    'huge',
#    'win',
#    '.'],
#   'positive'],
#  [['“',
#    '@',
#    'united',
#    ':',
#    '@',
#    'qlyss8',
#    'We',
#    'do',
#    "n't",
#    'want',
#    'our',
#    'customers',
#    'to',
#    'be',
#    'frustrated',
#    '.',
#    'Thank',
#    'you',
#    'for',
#    'your',
#    'patience',
#    '.',
#    '^JT',
#    '”',
#    'A',
#    'lovely',
#    'sentiment',
#    ',',
#    'but',
#    'not',
#    'a',
#    '$',
#    '180',
#    'one',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'belt',
#    'issues',
#    '.',
#    'Been',
#    'a',
#    'rough',
#    'day',
#    'for',
#    'them',
#    '.',
#    'Worst',
#    'part',
#    'is',
#    'traveling',
#    'with',
#    '9',
#    'month',
#    'old',
#    'and',
#    'having',
#    'to',
#    'wait',
#    'outside',
#    'in',
#    '85',
#    'degree'],
#   'negative'],
#  [['@',
#    'USAirways',
#    '@',
#    'Sb5551',
#    'Um',
#    ',',
#    'WE',
#    'knew',
#    'this',
#    'storm',
#    'was',
#    'coming',
#    ',',
#    '?',
#    'Is',
#    'why',
#    'did',
#    "n't",
#    'USeless',
#    'Air',
#    '?',
#    'Staff',
#    'accordingly',
#    'u',
#    'idiots',
#    '!'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'knows',
#    'whats',
#    'up',
#    '!',
#    'That',
#    '#',
#    'BlackHistoryMonth',
#    'commercial',
#    '.',
#    'Just',
#    'another',
#    'thing',
#    'to',
#    'add',
#    'to',
#    'reasons',
#    'why',
#    'I',
#    'fly',
#    'with',
#    '#',
#    'SouthWestAirlines'],
#   'positive'],
#  [['@',
#    'SouthwestAir',
#    'if',
#    'you',
#    'guys',
#    'fuck',
#    'this',
#    'up',
#    'again',
#    'I',
#    'will',
#    'never',
#    'forgive',
#    'you'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'what',
#    "'s",
#    'up',
#    'with',
#    'the',
#    'random',
#    'delay',
#    'on',
#    'flight',
#    '1729',
#    '?',
#    'Any',
#    'chance',
#    'of',
#    'it',
#    'being',
#    'a',
#    'false',
#    'alarm',
#    '?'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'I',
#    'do',
#    "n't",
#    'think',
#    'I',
#    "'ll",
#    'be',
#    'testing',
#    'those',
#    'waters',
#    'out',
#    'on',
#    'my',
#    'own',
#    'dime',
#    'again',
#    '.'],
#   'negative'],
#  [['@',
#    'jetblue',
#    'having',
#    'trouble',
#    'signing',
#    'in',
#    'to',
#    'TrueBlue',
#    'today',
#    ',',
#    'despite',
#    'right',
#    'credentials',
#    '.',
#    'getting',
#    '``',
#    'We',
#    'are',
#    'not',
#    'able',
#    'to',
#    'sign',
#    'you',
#    'in',
#    "''",
#    'msg',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'could',
#    "n't",
#    'make',
#    'flight',
#    ',',
#    'funds',
#    'forfeited',
#    'as',
#    'a',
#    'no',
#    'show',
#    '!',
#    '!',
#    'Was',
#    'trying',
#    'to',
#    'book',
#    'another',
#    'flight',
#    'using',
#    'those',
#    'funds',
#    ',',
#    'I',
#    "'m",
#    'out',
#    '.'],
#   'negative'],
#  [['Oh',
#    'wow',
#    '.',
#    '#',
#    'sm',
#    '“',
#    '@',
#    'JetBlue',
#    ':',
#    'Our',
#    'fleet',
#    "'s",
#    'on',
#    'fleek',
#    '.',
#    'http',
#    ':',
#    '//t.co/l0i8fnz3KU',
#    '”'],
#   'neutral'],
#  [['@',
#    'VirginAmerica',
#    'I',
#    'was',
#    'scheduled',
#    'for',
#    'SFO',
#    '2',
#    'DAL',
#    'flight',
#    '714',
#    'today',
#    '.',
#    'Changed',
#    'to',
#    '24th',
#    'due',
#    'weather',
#    '.',
#    'Looks',
#    'like',
#    'flight',
#    'still',
#    'on',
#    '?'],
#   'neutral'],
#  [['@',
#    'JetBlue',
#    'Do',
#    'your',
#    'TrueBlue',
#    'pages',
#    'not',
#    'work',
#    'on',
#    'Chrome',
#    'or',
#    'Safari',
#    '?',
#    'I',
#    'keep',
#    'getting',
#    'blank',
#    'pages',
#    'when',
#    'I',
#    'lick',
#    'on',
#    'the',
#    'TrueBlue',
#    'tab',
#    'on',
#    'your',
#    'site',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    '.',
#    'Thanks',
#    'United',
#    'for',
#    'the',
#    'no',
#    'running',
#    'water',
#    'and',
#    'Late',
#    'Flight',
#    'flight',
#    'from',
#    'Grand',
#    'Rapids',
#    'to',
#    'Denver'],
#   'negative'],
#  [['@',
#    'united',
#    'I',
#    'take',
#    'it',
#    'as',
#    'a',
#    'compliment',
#    'that',
#    'I',
#    'was',
#    'mistaken',
#    'several',
#    'times',
#    'as',
#    'a',
#    'member',
#    'of',
#    'your',
#    'staff',
#    'on',
#    'my',
#    'flight',
#    '...',
#    'time',
#    'to',
#    'remove',
#    'my',
#    'scarf',
#    ':',
#    ')'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    'you',
#    'will',
#    'extend',
#    'if',
#    'I',
#    'call',
#    'the',
#    'day',
#    'it',
#    'expires.why',
#    'ca',
#    "n't",
#    'it',
#    'just',
#    'be',
#    'extended',
#    'now',
#    '?',
#    '#',
#    'mightmismybrosgraduation'],
#   'negative'],
#  [['@',
#    'united',
#    'your',
#    'SFO-YYJ',
#    'fight',
#    'is',
#    'Cancelled',
#    'Flightled',
#    'several',
#    'times',
#    'each',
#    'week',
#    ',',
#    'why',
#    'even',
#    'bother',
#    '?'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'Yes',
#    'and',
#    'without',
#    'my',
#    'bags',
#    '.',
#    '2',
#    'first',
#    'class',
#    'tickets',
#    'to',
#    'Tahiti',
#    'would',
#    'be',
#    'nice',
#    '.',
#    'Just',
#    'saying'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'forgot',
#    'to',
#    'select',
#    'my',
#    'ksml',
#    'on',
#    'my',
#    'flight',
#    'to',
#    'LA',
#    'and',
#    'it',
#    "'s",
#    'a',
#    'few',
#    'minutes',
#    'under',
#    'the',
#    '24',
#    'hour',
#    'mark',
#    '.',
#    'Is',
#    'there',
#    'any',
#    'way',
#    'to',
#    'change',
#    'it',
#    '?'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'my',
#    'flight',
#    '1337',
#    'is',
#    'Cancelled',
#    'Flightled',
#    '.',
#    'Can',
#    'you',
#    'let',
#    'me',
#    'know',
#    'what',
#    'my',
#    'new',
#    'flight',
#    'info',
#    'is',
#    '?'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    '@',
#    'dfwairport',
#    'Have',
#    'been',
#    'trying',
#    'to',
#    'get',
#    'canx',
#    'flight',
#    'resched',
#    'since',
#    'noon',
#    '.',
#    'got',
#    '2',
#    'call',
#    'backs',
#    'but',
#    'call',
#    'disconnects',
#    'as',
#    'soon',
#    'as',
#    'I',
#    'answer'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'now',
#    'I',
#    'do',
#    "n't",
#    'get',
#    'the',
#    'common',
#    'courtesy',
#    'of',
#    'my',
#    'phone',
#    'call',
#    'answered',
#    '.',
#    'Either',
#    'policy',
#    'is',
#    'bad',
#    'or',
#    'people',
#    'should',
#    'be',
#    'fired',
#    '.',
#    '#',
#    'dissaponted'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'Call',
#    'me',
#    'when',
#    'you',
#    'do',
#    'and',
#    'we',
#    '’',
#    'll',
#    'have',
#    'to',
#    'hook',
#    'up',
#    '!'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    '@',
#    'USAirways',
#    '``',
#    'but',
#    'I',
#    'take',
#    'meds',
#    'that',
#    'make',
#    'me',
#    'severely',
#    'dehydrated',
#    "''",
#    '{',
#    'sigh',
#    '}'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'no',
#    'problem',
#    '...',
#    'just',
#    'funny',
#    'have',
#    'a',
#    'nice',
#    'day'],
#   'neutral'],
#  [['@',
#    'united',
#    'I',
#    'knew',
#    'I',
#    'should',
#    "'ve",
#    'flew',
#    '@',
#    'VirginAmerica',
#    'lol'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'We',
#    'had',
#    '2',
#    'great',
#    'flights',
#    'into',
#    'and',
#    'out',
#    'of',
#    'the',
#    'Bahamas',
#    ',',
#    'even',
#    'during',
#    'the',
#    'bad',
#    'weather',
#    'in',
#    'the',
#    'northeast',
#    ',',
#    'thanks',
#    'for',
#    'the',
#    'great',
#    'service',
#    '!',
#    '!',
#    '!'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'he',
#    'waited',
#    'over',
#    'two',
#    'hours',
#    'on',
#    'the',
#    'phone',
#    ',',
#    'had',
#    'to',
#    'book',
#    'and',
#    'get',
#    'to',
#    'MI',
#    ',',
#    'family',
#    'member',
#    'very',
#    'ill',
#    ',',
#    'time',
#    'of',
#    'the',
#    'essence'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'You',
#    "'re",
#    'clueless',
#    '.',
#    'A',
#    'kind',
#    'rez',
#    'agnt',
#    'contacted',
#    'USAir',
#    '4me',
#    'around',
#    'midnite',
#    ',',
#    'told',
#    'them',
#    'what',
#    'to',
#    'do',
#    '.',
#    'If',
#    'not',
#    'that',
#    'I',
#    "'d",
#    'have',
#    'missed',
#    'funeral',
#    '.'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'great',
#    'to',
#    'see',
#    'the',
#    'RedSox',
#    'plane',
#    'and',
#    'your',
#    'reminder',
#    'you',
#    '❤️NY',
#    'side',
#    'by',
#    'side',
#    'at',
#    'JFK',
#    '#',
#    'catsanddogslivingtogether',
#    'http',
#    ':',
#    '//t.co/KFUyYoKUFv'],
#   'positive'],
#  [['@', 'SouthwestAir', 'haha', ',', 'thanks', 'for', 'the', 'explanation'],
#   'positive'],
#  [['@',
#    'JetBlue',
#    'okay',
#    'thank',
#    'you',
#    '!',
#    'I',
#    "'ll",
#    'check',
#    'with',
#    'them',
#    'again',
#    '!'],
#   'positive'],
#  [['@',
#    'SouthwestAir',
#    'YES',
#    'please',
#    '....',
#    'How',
#    'do',
#    'we',
#    'get',
#    'that',
#    'companion',
#    'pass',
#    '?'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'trying',
#    'to',
#    'book',
#    'award',
#    'travel',
#    'leaving',
#    'on',
#    'red-eye',
#    'Sunday',
#    'night',
#    'after',
#    'midnight',
#    '.',
#    'Should',
#    'I',
#    'book',
#    'the',
#    'date',
#    'in',
#    'Sunday',
#    'or',
#    'Monday',
#    '?'],
#   'neutral'],
#  [['@',
#    'united',
#    'I',
#    'sure',
#    'did',
#    '.',
#    'I',
#    'had',
#    'to',
#    'drive',
#    'a',
#    'total',
#    'of',
#    '3',
#    'hours',
#    'to',
#    'get',
#    'my',
#    'own',
#    'bag',
#    '.',
#    'I',
#    "'d",
#    'like',
#    'to',
#    'explain',
#    'that',
#    'debacle',
#    'but',
#    'no',
#    'one',
#    'wants',
#    'to',
#    'talk',
#    'to',
#    'me',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'the',
#    'entire',
#    'flight',
#    'crew',
#    'on',
#    'flight',
#    '738',
#    'from',
#    'BOS',
#    'to',
#    'PHL',
#    'is',
#    'doing',
#    'a',
#    'wonderful',
#    'job',
#    'and',
#    'making',
#    'this',
#    'experience',
#    'not',
#    'totally',
#    'suck',
#    '.',
#    '😊'],
#   'positive'],
#  [['.',
#    '@',
#    'JetBlue',
#    'Ah',
#    'grasshopper',
#    ',',
#    'your',
#    'twitterz',
#    'kung',
#    'fu',
#    'no',
#    'good',
#    '.',
#    'Hire',
#    'geeks',
#    '.',
#    'http',
#    ':',
#    '//t.co/8MWItRi9kF'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'robocalls',
#    'me',
#    'with',
#    'another',
#    'Cancelled',
#    'Flightation',
#    '.',
#    'And',
#    'then',
#    'when',
#    'I',
#    'don',
#    '’',
#    't',
#    'accept',
#    'the',
#    'change',
#    'it',
#    'won',
#    '’',
#    't',
#    'let',
#    'me',
#    'connect',
#    'to',
#    'an',
#    'agent',
#    '.',
#    'Just',
#    'wow',
#    '.'],
#   'negative'],
#  [['@',
#    'southwestair',
#    'Grand',
#    'total',
#    'from',
#    'landing',
#    'to',
#    'getting',
#    'bag',
#    ':',
#    'one',
#    'hour',
#    '.',
#    'That',
#    "'s",
#    'very',
#    'sad',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    '@',
#    'Delta',
#    'Maybe',
#    '?',
#    'Long',
#    'trip',
#    ',',
#    'Late',
#    'Flight',
#    'night',
#    '&',
#    'amp',
#    ';',
#    'queues',
#    'at',
#    'baggage',
#    'claims',
#    'in',
#    'two',
#    'terminals',
#    ',',
#    'no',
#    'good',
#    '.',
#    'I',
#    'thought',
#    'I',
#    'paid',
#    'for',
#    'it',
#    '50',
#    '$',
#    'instead',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    '@',
#    'poisonpill76',
#    'im',
#    'in',
#    'same',
#    'boat',
#    '..',
#    '8am',
#    'flight',
#    'to',
#    'Jacksonville',
#    '...',
#    'Get',
#    'me',
#    'out',
#    'of',
#    'here',
#    '!',
#    '!'],
#   'negative'],
#  [['@',
#    'americanair',
#    'line',
#    'of',
#    '100+',
#    'people',
#    'to',
#    'rebook',
#    'at',
#    'MIA',
#    'now',
#    '.',
#    'Virtual',
#    'hold',
#    'on',
#    'rebook',
#    'line',
#    'just',
#    'hangs',
#    'up',
#    'during',
#    'call',
#    'back',
#    '.',
#    'http',
#    ':',
#    '//t.co/Upaz1eF3Dl'],
#   'negative'],
#  [['@',
#    'AlbertBreer',
#    'just',
#    'so',
#    'you',
#    'know',
#    'who',
#    'to',
#    'complain',
#    'to',
#    ';',
#    '-',
#    ')',
#    'RT',
#    '@',
#    'USAirways',
#    ':',
#    'Reminder',
#    ':',
#    'From',
#    '2/28',
#    ',',
#    'we',
#    '’',
#    'll',
#    'be',
#    'tweeting',
#    'from',
#    '@',
#    'AmericanAir',
#    '.'],
#   'neutral'],
#  [['@',
#    'united',
#    'Another',
#    'terrible',
#    'experience',
#    'with',
#    'United',
#    '.',
#    'Discrimination',
#    '.',
#    'Delays',
#    '.',
#    'And',
#    'no',
#    'help',
#    'from',
#    'customer',
#    'service',
#    '#',
#    'united',
#    '#',
#    'notimpressed'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'gate',
#    'agent',
#    'in',
#    'CLT',
#    'forced',
#    'me',
#    'to',
#    'check',
#    'bag',
#    'in',
#    'z1',
#    '&',
#    'amp',
#    ';',
#    'proceeded',
#    'to',
#    'allow',
#    'larger',
#    'bags',
#    '.',
#    'Huge',
#    'inconvenience',
#    'to',
#    'travel',
#    'plans',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'does',
#    'it',
#    'show',
#    'that',
#    'we',
#    'are',
#    'on',
#    'the',
#    'same',
#    'plane',
#    '?'],
#   'neutral'],
#  [['@',
#    'united',
#    'well',
#    ',',
#    'you',
#    'ca',
#    "n't",
#    'fix',
#    'me',
#    'missing',
#    'my',
#    'buddies',
#    '30th',
#    'bday',
#    'because',
#    'of',
#    'negligence',
#    'but',
#    'you',
#    'can',
#    'attempt',
#    'to',
#    'make',
#    'up',
#    'for',
#    'it',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    'No',
#    'first',
#    'class',
#    'passenger',
#    'should',
#    'have',
#    'to',
#    'pay',
#    'for',
#    'inflight',
#    'wifi',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'with',
#    'the',
#    'weather',
#    'mess',
#    'in',
#    'the',
#    'South',
#    ',',
#    'I',
#    'missed',
#    'my',
#    'connection',
#    'in',
#    'CLT',
#    '.',
#    'Impressed',
#    'though',
#    'with',
#    'the',
#    'Cust',
#    'Serv',
#    'phone',
#    'reps',
#    'today',
#    '.'],
#   'positive'],
#  [['@', 'AmericanAir', 'are', 'pets', 'allowed', 'in', 'first', 'class', '?'],
#   'neutral'],
#  [['@',
#    'JetBlue',
#    'I',
#    "'ve",
#    'spoken',
#    '2/emailed',
#    'JB',
#    'team',
#    'and',
#    'explained',
#    'situation',
#    '.',
#    'Didnt',
#    'seem',
#    'to',
#    'matter',
#    'to',
#    'anyone',
#    'other',
#    'than',
#    'me',
#    '.',
#    'I',
#    'guess',
#    'I',
#    'just',
#    'expected',
#    'more',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'Hi',
#    '!',
#    'Just',
#    'got',
#    'my',
#    'TSA',
#    'pre-check',
#    '#',
#    '&',
#    'amp',
#    ';',
#    'put',
#    'it',
#    'in',
#    'my',
#    'acct',
#    '.',
#    'But',
#    'it',
#    "'s",
#    'not',
#    'on',
#    'my',
#    'boarding',
#    'pass',
#    'for',
#    'a',
#    'flight',
#    'this',
#    'p.m.Can',
#    'it',
#    'be',
#    'updated',
#    '?'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'my',
#    'bag',
#    'landed',
#    '1',
#    'day',
#    'Late',
#    'Flight',
#    'at',
#    'sfo',
#    'at',
#    '11:40am',
#    '.',
#    'How',
#    'can',
#    'it',
#    'be',
#    '10:01pm',
#    'and',
#    'I',
#    'still',
#    'do',
#    "n't",
#    'have',
#    'it',
#    '?',
#    'Flight',
#    '719',
#    '2/22/14'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    '3611',
#    'was',
#    'supposed',
#    'to',
#    'depart',
#    'at',
#    '5:10pm',
#    'central',
#    '.',
#    'About',
#    'ready',
#    'to',
#    'close',
#    'the',
#    'door',
#    'at',
#    '7:34pm',
#    'central',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'I',
#    "'m",
#    'an',
#    'A-list',
#    'Preferred',
#    'customer',
#    'and',
#    'very',
#    'loyal',
#    'SWA',
#    '.',
#    'However',
#    ',',
#    'your',
#    'inflight',
#    'wifi',
#    'is',
#    'no',
#    'better',
#    'today',
#    'than',
#    'it',
#    'was',
#    '4',
#    'years',
#    'ago',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    'Either',
#    'is',
#    'fine',
#    '.',
#    'However',
#    ',',
#    'plundering',
#    'my',
#    'hard-earned',
#    'dollars',
#    'is',
#    'not',
#    'fine',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'thanks',
#    'for',
#    'reFlight',
#    'Booking',
#    'Problems',
#    'me',
#    'on',
#    'a',
#    'flight',
#    'and',
#    'then',
#    'leaving',
#    'my',
#    'luggage',
#    'in',
#    'NYC',
#    '.',
#    'Unbelievable',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'your',
#    'gate',
#    'agents',
#    'at',
#    'DFW',
#    'gate',
#    'B16',
#    'are',
#    'pathetic',
#    'tonight',
#    '.',
#    'Terrible',
#    'communication',
#    ',',
#    'stories',
#    'changing',
#    'and',
#    'apathetic'],
#   'negative'],
#  [['@',
#    'USAirways',
#    '-',
#    'been',
#    'on',
#    'hold',
#    'for',
#    'more',
#    'than',
#    '2.5',
#    'hours',
#    '-',
#    'this',
#    'after',
#    'not',
#    'getting',
#    'through',
#    'after',
#    '2',
#    'hours',
#    'on',
#    'hold',
#    'this',
#    'morning',
#    'with',
#    'no',
#    'answer',
#    '-',
#    'help',
#    '!'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'Help',
#    '-',
#    'I',
#    'left',
#    'my',
#    'Nikon',
#    'camera',
#    'under',
#    'the',
#    'seat',
#    'in',
#    'front',
#    'of',
#    'me',
#    '.',
#    'What',
#    'do',
#    'I',
#    'do',
#    '?'],
#   'neutral'],
#  [['@',
#    'USAirways',
#    'please',
#    'please',
#    'please',
#    'let',
#    'my',
#    'plane',
#    'back',
#    'to',
#    'the',
#    'gate',
#    'so',
#    'I',
#    'can',
#    'get',
#    'off',
#    'as',
#    'I',
#    'will',
#    'miss',
#    'connection',
#    'due',
#    'to',
#    'CLT',
#    'closing',
#    '.',
#    '2034'],
#   'neutral'],
#  [['@', 'SouthwestAir', 'too', 'Late', 'Flight', 'now'], 'negative'],
#  [['UA3388',
#    '@',
#    'united',
#    'was',
#    'Cancelled',
#    'Flightled',
#    'not',
#    'delayed',
#    '.',
#    'Re-Flight',
#    'Booking',
#    'Problems',
#    'still',
#    '90',
#    'miles',
#    'from',
#    'home',
#    '.',
#    'At',
#    'least',
#    'acknowledge',
#    'the',
#    'Cancelled',
#    'Flightlation',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'your',
#    'customer',
#    'service',
#    'is',
#    'inferior',
#    'to',
#    'that',
#    'of',
#    'a',
#    'nationalized',
#    'third',
#    'world',
#    'nation',
#    "'s",
#    'airline',
#    '.',
#    'Get',
#    'it',
#    'together',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'Just',
#    'realized',
#    'my',
#    'Luv',
#    'Voucher',
#    'expired',
#    'today',
#    '.',
#    ':',
#    '(',
#    'Any',
#    'chance',
#    'of',
#    'getting',
#    'some',
#    'luv',
#    'with',
#    'an',
#    'extension',
#    '?',
#    'Please',
#    '?',
#    '#',
#    'VeryLoyalCustomer'],
#   'neutral'],
#  [['@', 'AmericanAir', 'got', 'another', 'flight', '.', 'Thanks', 'you'],
#   'positive'],
#  [['@',
#    'united',
#    'very',
#    'disappointed',
#    'by',
#    'the',
#    'service',
#    'starting',
#    'from',
#    'gate',
#    'operator',
#    'at',
#    'BOS',
#    ',',
#    'who',
#    'was',
#    'rude',
#    'in',
#    'stopping',
#    'a',
#    'carry-on',
#    'bag',
#    '...'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'Airways',
#    'Lowered',
#    'to',
#    'Strong',
#    'Sell',
#    'at',
#    'Vetr',
#    'Inc.',
#    '(',
#    'JBLU',
#    ')',
#    '-',
#    'Mideast',
#    'Time',
#    'http',
#    ':',
#    '//t.co/yMMH9k4CBr'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    'no',
#    'HUMAN',
#    'contact',
#    'for',
#    '2',
#    'mths',
#    'from',
#    '@',
#    'AmericanAir',
#    'cust',
#    'relations',
#    'or',
#    'refund',
#    'dept',
#    '.',
#    'If',
#    'ever',
#    'a',
#    'problem',
#    'do',
#    'u',
#    'have',
#    'humans',
#    'I',
#    'can',
#    'talk',
#    'to',
#    '?'],
#   'negative'],
#  [['@',
#    'united',
#    'thanks',
#    'for',
#    'nothing',
#    '.',
#    'Really',
#    '?',
#    '!',
#    '?',
#    '60',
#    'minute',
#    'wait',
#    'times',
#    'when',
#    'I',
#    "'ve",
#    'had',
#    'to',
#    'call',
#    'back',
#    '4x',
#    '.',
#    'That',
#    "'s",
#    '240minute',
#    'wait',
#    'times',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    'flight',
#    'ua90',
#    'is',
#    'taking',
#    'off',
#    'now',
#    'after',
#    '1750',
#    'was',
#    'delayed',
#    'over',
#    '4',
#    'hrs',
#    '30',
#    'passengers',
#    'to',
#    'miss',
#    'their',
#    'flight',
#    'to',
#    'tel',
#    'aviv'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'Why',
#    'close',
#    'prechk',
#    'at',
#    '8PM',
#    'on',
#    'a',
#    'Sunday',
#    'at',
#    'JFK',
#    '?',
#    '#',
#    'annoying'],
#   'negative'],
#  [['@',
#    'united',
#    'what',
#    'a',
#    'long',
#    'day',
#    'of',
#    'delays',
#    '.',
#    'Please',
#    'get',
#    'us',
#    'to',
#    'Dallas',
#    'tonight',
#    '!',
#    '!',
#    '!',
#    '!',
#    'Fingers',
#    'crossed',
#    '!',
#    '!',
#    '!',
#    '#',
#    'winterstorm2015',
#    '#',
#    'whichisworsedenordfw',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'If',
#    'a',
#    'travel',
#    'advisory',
#    'is',
#    'posted',
#    'for',
#    'DEN',
#    ',',
#    'can',
#    'I',
#    'then',
#    'make',
#    'changes',
#    'to',
#    'my',
#    'ticket',
#    '?',
#    'Anything',
#    'I',
#    'need',
#    'to',
#    'know',
#    'before',
#    'I',
#    'call',
#    '?'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    'I',
#    'know',
#    'it',
#    'is',
#    'hard',
#    'to',
#    'predict',
#    ',',
#    'but',
#    'how',
#    'are',
#    'flights',
#    'from',
#    'Dallas',
#    'to',
#    'Nashville',
#    'tomorrow',
#    'AM',
#    '?'],
#   'neutral'],
#  [['@',
#    'united',
#    'How',
#    'is',
#    'this',
#    'considered',
#    '``',
#    'on',
#    'time',
#    "''",
#    'if',
#    'it',
#    "'s",
#    'arriving',
#    'at',
#    'destination',
#    'half',
#    'hour',
#    'Late',
#    'Flightr',
#    'than',
#    'scheduled',
#    '?',
#    'http',
#    ':',
#    '//t.co/YMFTw1uyHr'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'You',
#    'have',
#    'very',
#    'unhappy',
#    'customer',
#    '.',
#    'After',
#    'waiting',
#    '20',
#    'min',
#    'on',
#    'hold',
#    ',',
#    'rude',
#    '&',
#    'amp',
#    ';',
#    'uncaring',
#    'rep',
#    'has',
#    'now',
#    'frozen',
#    'my',
#    'acct',
#    '.',
#    'ca',
#    "n't",
#    'print',
#    'bdng',
#    'pass',
#    '!'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'if',
#    'I',
#    'had',
#    'made',
#    'as',
#    'many',
#    'mistakes',
#    'as',
#    'you',
#    'in',
#    'as',
#    'short',
#    'a',
#    'period',
#    'of',
#    'time',
#    '.',
#    'I',
#    'would',
#    'I',
#    'have',
#    'lost',
#    'my',
#    'job',
#    'at',
#    'this',
#    'point',
#    '!',
#    '!',
#    '!'],
#   'negative'],
#  [['@',
#    'united',
#    '2',
#    'Cancelled',
#    'Flighted',
#    'flights',
#    'Late',
#    'Flightr',
#    ',',
#    'agent',
#    'claimed',
#    'she',
#    'put',
#    'me',
#    'on',
#    'a',
#    'new',
#    'flight',
#    'but',
#    'then',
#    'Cancelled',
#    'Flighted',
#    'it',
#    '.',
#    'Coworker',
#    'got',
#    'on',
#    'flight-',
#    'now',
#    'delayed',
#    '.',
#    'Now',
#    '?'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    '#',
#    'tfw1',
#    '@',
#    'JimCramer',
#    '@',
#    'AARP',
#    'TY-Spent',
#    'total',
#    'of',
#    '3',
#    'hrs',
#    'and',
#    '20',
#    'mins',
#    'holding',
#    '.',
#    'Cell',
#    'battery',
#    'died',
#    '.',
#    'Finally',
#    'made',
#    'arrangements',
#    'w',
#    'kind',
#    'Rep'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'in',
#    'line',
#    'at',
#    'SFO',
#    '.',
#    'Customer',
#    'service',
#    'is',
#    'rude',
#    ',',
#    'disorganized',
#    ',',
#    'and',
#    'congested',
#    '.',
#    'Very',
#    'dissapointing',
#    '.'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'thank',
#    'you',
#    'for',
#    'taking',
#    'care',
#    'of',
#    'me',
#    'with',
#    'a',
#    'drink',
#    'since',
#    'my',
#    'in-flight',
#    'entertainment',
#    'was',
#    "n't",
#    'working',
#    '#',
#    'goodcustomerservice'],
#   'positive'],
#  [['@', 'united', 'please', 'help', 'http', ':', '//t.co/t5mRj5Yw6I'],
#   'neutral'],
#  [['@',
#    'USAirways',
#    'on',
#    'flight',
#    '#',
#    '556',
#    'delayed',
#    '#',
#    'connection',
#    'help',
#    'for',
#    'flight',
#    '#',
#    '561',
#    '#',
#    'help',
#    'via',
#    'email'],
#   'negative'],
#  [['@',
#    'USAirways',
#    '$',
#    '75',
#    'for',
#    'that',
#    'uncertainty',
#    '?',
#    'I',
#    'know',
#    'u',
#    'run',
#    'an',
#    'account',
#    ';',
#    'u',
#    'do',
#    "n't",
#    'create',
#    'policy',
#    '.',
#    'But',
#    'it',
#    "'s",
#    'an',
#    'undue',
#    'penalty',
#    'for',
#    'a',
#    'job',
#    "req'ing",
#    'flexibility'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'is',
#    'my',
#    'favorite',
#    'airline',
#    '!',
#    'I',
#    'ca',
#    "n't",
#    'wait',
#    'to',
#    'book',
#    'my',
#    'flight',
#    'to',
#    'New',
#    'Orleans',
#    'for',
#    'my',
#    'trip',
#    'in',
#    'April',
#    '!',
#    '!',
#    ':',
#    ')',
#    ':',
#    ')'],
#   'positive'],
#  [['@',
#    'USAirways',
#    '@',
#    'usairways',
#    '-Really',
#    '?',
#    'U',
#    'land',
#    'me',
#    'in',
#    'Philly',
#    '1.5',
#    'hours',
#    'before',
#    'my',
#    'flight',
#    ',',
#    'wait',
#    '1.5',
#    'hours',
#    'behind',
#    'a',
#    'plane',
#    'you',
#    'got',
#    'stuck',
#    ','],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'Alright',
#    'I',
#    'hope',
#    '.',
#    'My',
#    'JetBlue',
#    'app',
#    'is',
#    'showing',
#    'a',
#    'change',
#    'in',
#    'my',
#    'seats',
#    'and',
#    'online',
#    'shows',
#    'an',
#    'a320',
#    '.',
#    'Do',
#    "n't",
#    'want',
#    'any',
#    'surprises'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    '@',
#    'tennetexan',
#    'Too',
#    'bad',
#    'there',
#    "'s",
#    'only',
#    ',',
#    'like',
#    ',',
#    '3',
#    'people',
#    'on',
#    'that',
#    'team',
#    ',',
#    'then',
#    '.',
#    'Because',
#    'this',
#    'is',
#    'next',
#    'level',
#    'unreal',
#    '.'],
#   'negative'],
#  [['@', 'AmericanAir', 'yikes', '.'], 'neutral'],
#  [['@',
#    'united',
#    'Exhausted',
#    '&',
#    'amp',
#    ';',
#    'frustrated',
#    '!',
#    'Link',
#    'to',
#    'a',
#    'FB',
#    'post',
#    'abt',
#    'my',
#    'travel',
#    'issue',
#    'https',
#    ':',
#    '//t.co/LaRKC8vc4s'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'Thanks',
#    ',',
#    'it',
#    "'s",
#    'for',
#    'next',
#    'weekend',
#    'though',
#    'so',
#    'my',
#    'guess',
#    'is',
#    'it',
#    'will',
#    'only',
#    'go',
#    'higher',
#    '.'],
#   'neutral'],
#  [['@',
#    'VirginAmerica',
#    'If',
#    'only',
#    'you',
#    'guys',
#    'had',
#    'flights',
#    'from',
#    'CMH',
#    '.'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'We',
#    'tried',
#    'with',
#    'multiple',
#    'people',
#    '.',
#    'I',
#    'already',
#    'sat',
#    'on',
#    'the',
#    'phone',
#    'for',
#    'an',
#    'hour',
#    'and',
#    'a',
#    'half',
#    'and',
#    'got',
#    'nowhere',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    '@',
#    'karabuxthomps',
#    'Yeah',
#    ',',
#    'I',
#    'have',
#    'a',
#    'lot',
#    'of',
#    'questions',
#    ',',
#    'number',
#    'one',
#    ':',
#    'how',
#    'dare',
#    'you'],
#   'negative'],
#  [['“',
#    '@',
#    'JetBlue',
#    ':',
#    '@',
#    '2littlebirds',
#    'Beautiful',
#    'shot',
#    '..',
#    'Thanks',
#    'for',
#    'sharing',
#    '.',
#    'Using',
#    '#',
#    'FlyFi',
#    'to',
#    'post',
#    '?',
#    ';',
#    ')',
#    '”',
#    'Your',
#    'welcome',
#    '!',
#    'Not',
#    'on',
#    'this',
#    'flight',
#    '.',
#    'It',
#    'was',
#    'a',
#    'quickie',
#    ';',
#    ')'],
#   'positive'],
#  [['@',
#    'SouthwestAir',
#    'your',
#    'phone',
#    'lines',
#    'suck',
#    '.',
#    'I',
#    'have',
#    'a',
#    'dilemma',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'Flight',
#    '1700',
#    '.',
#    '(',
#    'PHX',
#    'TO',
#    'LAX',
#    ')',
#    'Wheels',
#    'stop',
#    '.',
#    'Glad',
#    'to',
#    'be',
#    'home',
#    '!',
#    'Thanks',
#    'to',
#    'the',
#    'professionals',
#    'both',
#    'up',
#    'front',
#    'and',
#    'in',
#    'the',
#    'cabin',
#    '!',
#    '!',
#    '!'],
#   'positive'],
#  [['@',
#    'VirginAmerica',
#    '#',
#    'wtf',
#    'I',
#    'paid',
#    'for',
#    'direct',
#    'flight',
#    'on',
#    'purpose',
#    'not',
#    'to',
#    'have',
#    'to',
#    'stop',
#    'for',
#    'fuel',
#    'exhausted',
#    'frequent',
#    'flier',
#    'and',
#    'nothing',
#    'for',
#    'inconvenience',
#    '!'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'Thanks',
#    'so',
#    'much',
#    'for',
#    'talking',
#    'to',
#    'me',
#    '!',
#    'The',
#    'article',
#    'about',
#    '#',
#    'Twitter',
#    'chats',
#    'came',
#    'out',
#    'great',
#    '!',
#    'http',
#    ':',
#    '//t.co/rKorHvR9z1',
#    '#',
#    'contentmarketing'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'Thanks',
#    'guys',
#    ',',
#    'you',
#    'got',
#    'it',
#    '.',
#    'I',
#    "'m",
#    'heading',
#    'to',
#    'Milan',
#    'on',
#    'Wednesday',
#    ',',
#    'so',
#    'big',
#    'week',
#    'with',
#    'the',
#    'AA',
#    'family',
#    ':',
#    ')'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'Your',
#    'people',
#    'on',
#    'the',
#    'phone',
#    'ca',
#    "n't",
#    'see',
#    'those',
#    '?',
#    'And',
#    'to',
#    'have',
#    'it',
#    'be',
#    'over',
#    '$',
#    '800',
#    'difference',
#    '.',
#    'That',
#    "'s",
#    'a',
#    'poor',
#    'process',
#    'then',
#    '...'],
#   'negative'],
#  [['@',
#    'united',
#    'Ruth',
#    'was',
#    'VERY',
#    'helpful',
#    'in',
#    're-routing',
#    'us',
#    'to',
#    'Punta',
#    'Cana',
#    'when',
#    'Dulles',
#    'connection',
#    'failed',
#    '.',
#    'Other',
#    'reps-',
#    'NOT',
#    'so',
#    'helpful',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'I',
#    'have',
#    'a',
#    'flight',
#    'to',
#    'Vegas',
#    'coming',
#    'up',
#    'soon',
#    ',',
#    'but',
#    'haven',
#    '’',
#    't',
#    'received',
#    'any',
#    'drink',
#    'tickets',
#    'Late',
#    'Flightly',
#    '.',
#    'Can',
#    'you',
#    'help',
#    'me',
#    'out',
#    '?'],
#   'neutral'],
#  [['@', 'JetBlue', 'flight16', '?'], 'neutral'],
#  [['@',
#    'USAirways',
#    'honestly',
#    '-',
#    'how',
#    'is',
#    'it',
#    'quickly',
#    'as',
#    'possible',
#    'I',
#    "'ve",
#    'been',
#    'on',
#    'hold',
#    'sine',
#    '9:50pm',
#    '?',
#    'Everyone',
#    'that',
#    'answers',
#    'has',
#    'to',
#    'send',
#    'me',
#    'to',
#    'someone',
#    'else',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'almost',
#    '2',
#    'hours',
#    'on',
#    'hold',
#    ',',
#    '2',
#    'hours',
#    'of',
#    'my',
#    'life',
#    'I',
#    'ca',
#    "n't",
#    'get',
#    'back',
#    '....',
#    'Thanks',
#    'http',
#    ':',
#    '//t.co/IyUZM2PUVS'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'found',
#    'great',
#    'prices',
#    'thru',
#    'US',
#    'Air',
#    'for',
#    'honeymoon',
#    '.',
#    'Website',
#    'wont',
#    'work',
#    'and',
#    'been',
#    'on',
#    'hold',
#    'for',
#    'more',
#    'than',
#    'a',
#    'hour',
#    'now',
#    'after',
#    'being',
#    'told',
#    '10',
#    'min'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'your',
#    'wifi',
#    'is',
#    'a',
#    'lie',
#    'and',
#    'i',
#    'hate',
#    'you'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'I',
#    '’',
#    'm',
#    'still',
#    'disappointed',
#    'that',
#    'it',
#    'is',
#    'apparently',
#    'ok',
#    'for',
#    'a',
#    'Flight',
#    'Attendant',
#    'who',
#    'isn',
#    '’',
#    't',
#    'up',
#    'on',
#    'current',
#    'policy',
#    'to',
#    'argue',
#    'with',
#    'a',
#    'traveler',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'looks',
#    'like',
#    'you',
#    'lost',
#    'another',
#    'customer',
#    'when',
#    'you',
#    'stranded',
#    '@',
#    '41CGQueen',
#    'at',
#    'CLT',
#    'she',
#    'vows',
#    'never',
#    'to',
#    'fly',
#    'with',
#    'you',
#    'again',
#    '#',
#    'smoothtransition'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'Although',
#    'it',
#    'was',
#    "n't",
#    'totally',
#    'the',
#    'answer',
#    'I',
#    'was',
#    'looking',
#    'for',
#    ',',
#    'I',
#    'appreciate',
#    'the',
#    'prompt',
#    'response',
#    '.'],
#   'positive'],
#  [['@',
#    'JetBlue',
#    'why',
#    'would',
#    "n't",
#    'you',
#    'just',
#    'credit',
#    'it',
#    'right',
#    'to',
#    'my',
#    'account',
#    'instead',
#    'of',
#    'having',
#    'a',
#    'separate',
#    'sign',
#    'on',
#    '.',
#    'That',
#    'seems',
#    'pretty',
#    'ridiculous',
#    '.'],
#   'negative'],
#  [['@', 'SouthwestAir', 'your', 'employees', 'were', 'great', '!'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'not',
#    'best',
#    'pleased',
#    'with',
#    'service',
#    'so',
#    'far',
#    '.',
#    'On',
#    'our',
#    'third',
#    'gate',
#    'and',
#    'still',
#    'no',
#    'guarantee',
#    'that',
#    'it',
#    "'s",
#    'the',
#    'correct',
#    'one',
#    ':',
#    '('],
#   'negative'],
#  [['@',
#    'USAirways',
#    'Every',
#    'time',
#    'I',
#    'try',
#    ',',
#    'the',
#    'line',
#    'is',
#    'disconnected',
#    'b/c',
#    'the',
#    'system',
#    'says',
#    'you',
#    'have',
#    'too',
#    'many',
#    'calls',
#    '.',
#    'Glad',
#    'your',
#    'screw',
#    'up',
#    'matters',
#    'so',
#    'much',
#    'to',
#    'you'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'flight',
#    '691',
#    'from',
#    'bos',
#    'to',
#    'Tampa',
#    'takeoff',
#    '40',
#    'min',
#    'Late',
#    'Flight'],
#   'negative'],
#  [['@',
#    'VirginAmerica',
#    'Thanks',
#    'so',
#    'much',
#    'for',
#    'the',
#    'awesome',
#    'support',
#    ',',
#    'you',
#    'guys',
#    'rock',
#    '!'],
#   'positive'],
#  [['@',
#    'VirginAmerica',
#    'why',
#    'are',
#    'your',
#    'first',
#    'fares',
#    'in',
#    'May',
#    'over',
#    'three',
#    'times',
#    'more',
#    'than',
#    'other',
#    'carriers',
#    'when',
#    'all',
#    'seats',
#    'are',
#    'available',
#    'to',
#    'select',
#    '?',
#    '?',
#    '?'],
#   'negative'],
#  [['@',
#    'united',
#    'Thank',
#    'you',
#    '.',
#    'Took',
#    'care',
#    'of',
#    'everything',
#    'and',
#    'made',
#    'it',
#    'right',
#    '.',
#    'That',
#    "'s",
#    'the',
#    'experience',
#    'I',
#    "'m",
#    'used',
#    'to',
#    '.',
#    'Opened',
#    'the',
#    'app',
#    'to',
#    'find',
#    'flight',
#    'changed',
#    '.'],
#   'positive'],
#  [['@',
#    'SouthwestAir',
#    'I',
#    'hate',
#    'evolved',
#    'seating',
#    '.',
#    'knees',
#    'in',
#    'the',
#    'seat',
#    'pocket',
#    'http',
#    ':',
#    '//t.co/forNpF69Ky'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'this',
#    'is',
#    'how',
#    'concerned',
#    'your',
#    'gate',
#    'attendants',
#    'at',
#    'C26',
#    'are',
#    'this',
#    'afternoon',
#    '.',
#    '#',
#    'nocommunication',
#    '#',
#    'nocrew',
#    'http',
#    ':',
#    '//t.co/hFjYN2vtVj'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'you',
#    'were',
#    'always',
#    'my',
#    'go',
#    'to',
#    '.',
#    'What',
#    'happened',
#    '?',
#    'Airbus',
#    'over',
#    'Boeing',
#    ',',
#    'and',
#    'now',
#    'no',
#    'customer',
#    'service',
#    '?'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'Had',
#    'a',
#    'great',
#    'trip',
#    'this',
#    'past',
#    'week',
#    'to',
#    'Vegas',
#    'for',
#    'work',
#    ';',
#    'and',
#    'had',
#    'this',
#    'pic',
#    'over',
#    'the',
#    'Southwest',
#    'on',
#    'Southwest',
#    '!',
#    'http',
#    ':',
#    '//t.co/a3YCFlaLxV'],
#   'positive'],
#  [['@',
#    'united',
#    'I',
#    'was',
#    'denied',
#    'use',
#    'of',
#    'a',
#    'rear',
#    'facing',
#    'car',
#    'seat',
#    'on',
#    'UA5025',
#    ',',
#    'an',
#    'ERJ145',
#    '.',
#    'Can',
#    'you',
#    'confirm',
#    'the',
#    'actual',
#    'policy',
#    '?'],
#   'negative'],
#  [['@',
#    'united',
#    'worst',
#    'AIRLINE',
#    'BEWARE',
#    'THEY',
#    'DO',
#    'NOT',
#    'MAINTAIN',
#    'THERE',
#    'PLAIN',
#    'BEEN',
#    'ON',
#    'THE',
#    'RUNWAY',
#    'THE',
#    'PAST',
#    '4',
#    'HOURS',
#    '!',
#    '!',
#    '!',
#    '/'],
#   'negative'],
#  [['@',
#    'southwestair',
#    '#',
#    'fattuesday',
#    'Great',
# ...
#    'recovery'],
#   'positive'],
#  [['@',
#    'united',
#    'not',
#    'yet',
#    '.',
#    'I',
#    'complained',
#    'about',
#    'the',
#    'guy',
#    'who',
#    'checked',
#    'my',
#    'luggage',
#    'in',
#    'as',
#    'he',
#    'was',
#    'throwing',
#    'the',
#    'bags',
#    'around',
#    '.',
#    'Unfortunate',
#    'coincidence',
#    'I',
#    'hope',
#    '?'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'is',
#    'hiring',
#    'for',
#    'their',
#    'Emerging',
#    'Leader',
#    'Development',
#    'Program-',
#    'Last',
#    'day',
#    'to',
#    'apply',
#    'is',
#    'TODAY',
#    '!',
#    'Apply',
#    'here',
#    ':',
#    'http',
#    ':',
#    '//t.co/jLHM0x7UkB'],
#   'neutral'],
#  [['@',
#    'USAirways',
#    'instead',
#    'of',
#    'tweeting',
#    'your',
#    'customers',
#    'apologizing',
#    'why',
#    'do',
#    "n't",
#    'you',
#    'pick',
#    'up',
#    'your',
#    'phone'],
#   'negative'],
#  [['@',
#    'United',
#    'says',
#    'we',
#    'had',
#    'a',
#    'weather',
#    'delay',
#    'in',
#    '#',
#    'YXE',
#    'this',
#    'morning',
#    '.',
#    'The',
#    '``',
#    'weather',
#    "''",
#    'did',
#    "n't",
#    'affect',
#    'any',
#    'other',
#    'airline',
#    '.',
#    '#',
#    'UA6136',
#    'http',
#    ':',
#    '//t.co/4JdvK8tCqx'],
#   'negative'],
#  [['@',
#    'united',
#    'lost',
#    '4',
#    'loyal',
#    'customers',
#    'and',
#    'mileage',
#    'plus',
#    'card',
#    'holders',
#    '.',
#    'We',
#    'could',
#    'have',
#    'driven',
#    'to',
#    'Florida',
#    'from',
#    'Pa',
#    'quicker',
#    'both',
#    'ways',
#    '!',
#    'Worst',
#    'trip',
#    'ever',
#    '!'],
#   'negative'],
#  [['@',
#    'united',
#    'Every',
#    'United',
#    'flight',
#    'between',
#    'Saipan',
#    'and',
#    'Guam',
#    'is',
#    'an',
#    'adventure',
#    '!',
#    'You',
#    'never',
#    'know',
#    'when',
#    '@',
#    'CapeAir',
#    "'s",
#    'old',
#    'plane',
#    'will',
#    'be',
#    'operational',
#    ':',
#    ')'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'My',
#    'flights',
#    'tomorrow',
#    'were',
#    'Cancelled',
#    'Flighted',
#    ',',
#    'ca',
#    "n't",
#    'do',
#    'anything',
#    'online',
#    ',',
#    'and',
#    'ca',
#    "n't",
#    'get',
#    'through',
#    'on',
#    'phone',
#    '.',
#    'Help',
#    '?'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'Thanks',
#    '!',
#    'Sent',
#    'you',
#    'DM',
#    're',
#    ':',
#    'baggage',
#    'issues',
#    '.'],
#   'positive'],
#  [['@',
#    'united',
#    'Would',
#    'be',
#    'helpful',
#    'if',
#    'you',
#    'could',
#    'refresh',
#    'boarding',
#    'time',
#    'info',
#    'on',
#    'boarding',
#    'passes',
#    'for',
#    'delayed',
#    'flights'],
#   'negative'],
#  [['@', 'AmericanAir', 'boom', '.', 'http', ':', '//t.co/PzGc6Jch7n'],
#   'neutral'],
#  [['@',
#    'united',
#    'I',
#    "'m",
#    'try',
#    'to',
#    'upgrade',
#    'my',
#    'seats',
#    'to',
#    'first',
#    'class',
#    'but',
#    'the',
#    'wait',
#    'time',
#    'on',
#    'the',
#    'phone',
#    'is',
#    '40',
#    'minutes',
#    '...',
#    'can',
#    'you',
#    'help',
#    '?'],
#   'negative'],
#  [['@', 'JetBlue', '6am', 'Austin', 'to', 'JFK'], 'neutral'],
#  [['@', 'AmericanAir', 'sure', ',', 'thank', 'you', '!'], 'positive'],
#  [['@',
#    'JetBlue',
#    'when',
#    'will',
#    'the',
#    'system',
#    'be',
#    'up',
#    'and',
#    'running',
#    '?'],
#   'neutral'],
#  [['X____x',
#    'RT',
#    '@',
#    'JetBlue',
#    ':',
#    'Our',
#    'fleet',
#    "'s",
#    'on',
#    'fleek',
#    '.',
#    'http',
#    ':',
#    '//t.co/Y39YzDpBvU'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'probably',
#    'had',
#    'money',
#    'on',
#    '@',
#    'BensonHenderson',
#    'they',
#    'said',
#    'to',
#    'hell',
#    'with',
#    '@',
#    'Cowboycerrone',
#    'lol'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    '-',
#    'Whoooo',
#    'Hooooo',
#    'just',
#    'crossed',
#    '25,367',
#    '!',
#    '!',
#    '!',
#    'At',
#    'my',
#    'current',
#    'pace',
#    'I',
#    'should',
#    'reach',
#    '152,202',
#    'for',
#    'the',
#    'year',
#    '.'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'I',
#    'spoke',
#    'with',
#    'a',
#    'customer',
#    'service',
#    'rep',
#    'who',
#    'was',
#    'rude',
#    'and',
#    'curt',
#    'and',
#    'transferred',
#    'me',
#    'to',
#    'eternal',
#    'hold',
#    '.',
#    'Sad',
#    '.',
#    '#',
#    'badservice',
#    '#',
#    'mergerdisaster'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'is',
#    'alright',
#    'with',
#    'me',
#    '.',
#    'Please',
#    'give',
#    'Scott',
#    'F',
#    'at',
#    'BDL',
#    'a',
#    'bonus',
#    'for',
#    'excellent',
#    'customer',
#    'service'],
#   'positive'],
#  [['@',
#    'JetBlue',
#    'Oh',
#    'no',
#    '!',
#    'I',
#    'thought',
#    'it',
#    'did',
#    '.',
#    ':',
#    '('],
#   'negative'],
#  [['@',
#    'USAirways',
#    'thank',
#    'you',
#    'for',
#    'continuing',
#    'to',
#    'be',
#    'the',
#    'worst',
#    'airline',
#    'out',
#    '.',
#    'Did',
#    "n't",
#    'need',
#    'that',
#    'extra',
#    'hour',
#    'of',
#    'sleep',
#    'after',
#    '29',
#    'hours',
#    'of',
#    'travel',
#    'anyway'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'can',
#    'I',
#    'get',
#    'a',
#    'free',
#    'ticket',
#    'to',
#    'Hawaii',
#    'for',
#    'being',
#    'fabulous'],
#   'neutral'],
#  [['@', 'SouthwestAir', 'yes', 'can', 'do'], 'neutral'],
#  [['@',
#    'AmericanAir',
#    'emailed',
#    'AAdvantage',
#    'for',
#    'status',
#    'match',
#    '...',
#    'still',
#    'waiting',
#    '.',
#    'Ca',
#    "n't",
#    'wait',
#    'to',
#    'move',
#    'from',
#    '@',
#    'united',
#    'but',
#    'help',
#    'me',
#    'out',
#    'here',
#    ':',
#    ')'],
#   'negative'],
#  [['@',
#    'VirginAmerica',
#    'has',
#    'flight',
#    'number',
#    '276',
#    'from',
#    'SFO',
#    'to',
#    'Cabo',
#    'San',
#    'Lucas',
#    'arrived',
#    'yet',
#    '?'],
#   'neutral'],
#  [['@',
#    'JetBlue',
#    'my',
#    'request',
#    'has',
#    'nothing',
#    'to',
#    'do',
#    'with',
#    'rescheduling',
#    '.',
#    'But',
#    'customer',
#    'service',
#    'has',
#    'such',
#    'a',
#    'bad',
#    'attitude',
#    'today',
#    '.',
#    '#',
#    'badservice'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'right',
#    ',',
#    'can',
#    'you',
#    'use',
#    'a',
#    'shuttle',
#    'ticket',
#    'from',
#    'LGA',
#    'to',
#    'BOS',
#    'for',
#    'any',
#    'shuttle',
#    'flight',
#    '?',
#    'Probably',
#    'gon',
#    'na',
#    'miss',
#    'the',
#    '4pm',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'a',
#    '$',
#    '75',
#    'change',
#    'is',
#    'ok',
#    'most',
#    'of',
#    'the',
#    'time',
#    'but',
#    'if',
#    'there',
#    'r',
#    'open',
#    'seats',
#    'on',
#    'earlier',
#    'flt',
#    'and',
#    'no',
#    'chkd',
#    'bag',
#    ',',
#    'why',
#    'not',
#    'let',
#    'someone',
#    'fly',
#    'standby',
#    '?'],
#   'neutral'],
#  [['@',
#    'USAirways',
#    'missing',
#    'our',
#    'connection',
#    'due',
#    'to',
#    'delay',
#    'out',
#    'of',
#    '@',
#    'LAS',
#    '.',
#    'Told',
#    'not',
#    'looking',
#    'good',
#    'for',
#    'tmrw',
#    'either',
#    '.',
#    'We',
#    'will',
#    'be',
#    'stuck',
#    'in',
#    '#',
#    'CLT',
#    '.',
#    'Help',
#    '!'],
#   'negative'],
#  [['@',
#    'united',
#    'are',
#    'the',
#    'miles',
#    'going',
#    'to',
#    'be',
#    'restructured',
#    '?',
#    'Help',
#    'a',
#    'silver',
#    'status',
#    'brotha',
#    'out',
#    '!',
#    'I',
#    'thought',
#    'I',
#    'was',
#    'winning',
#    'with',
#    'you',
#    'guys',
#    'until',
#    'today',
#    'lol'],
#   'negative'],
#  [['@',
#    'VirginAmerica',
#    'currently',
#    'in',
#    'minute',
#    '10',
#    'of',
#    'being',
#    'on',
#    'hold',
#    'with',
#    'cust',
#    '.',
#    'service',
#    '.',
#    'Do',
#    'I',
#    'need',
#    'to',
#    'do',
#    'anything',
#    'to',
#    'add',
#    'a',
#    'lap',
#    'child',
#    'to',
#    'my',
#    'reservation',
#    '?'],
#   'negative'],
#  [['@',
#    'united',
#    'Need',
#    'to',
#    'change',
#    'flight',
#    'from',
#    'this',
#    'Tuesday',
#    'to',
#    'sooner',
#    'to',
#    'attend',
#    'to',
#    'ailing',
#    'parent',
#    'in',
#    'FL',
#    ',',
#    'Need',
#    'help',
#    '!',
#    '!',
#    '#',
#    'custserv'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    'can',
#    'you',
#    'answer',
#    'the',
#    'phone',
#    'so',
#    'I',
#    'can',
#    'change',
#    'my',
#    'flight',
#    'plans',
#    '.',
#    'Srsly',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'AMAZING',
#    'c/s',
#    'today',
#    'by',
#    'SW',
#    'thank',
#    'you',
#    'SO',
#    'very',
#    'much',
#    '.',
#    'This',
#    'is',
#    'the',
#    'reason',
#    'we',
#    'fly',
#    'you',
#    '#',
#    'southwest'],
#   'positive'],
#  [['@',
#    'united',
#    'I',
#    'took',
#    'the',
#    'exact',
#    'same',
#    'aircraft',
#    'in',
#    'to',
#    'LAX',
#    '3',
#    'days',
#    'ago',
#    '.',
#    'It',
#    'fit',
#    ',',
#    'no',
#    'problem',
#    '.',
#    'The',
#    'agent',
#    'today',
#    'told',
#    'some',
#    'nonsense',
#    'about',
#    'a',
#    'policy',
#    'change'],
#   'negative'],
#  [['@',
#    'united',
#    '@',
#    'estellevw',
#    'does',
#    'she',
#    'need',
#    'to',
#    'complain',
#    'on',
#    'Twitter',
#    'for',
#    'the',
#    'refund',
#    'or',
#    'is',
#    'it',
#    'auto-applied',
#    '?'],
#   'neutral'],
#  [['@',
#    'united',
#    'fails',
#    'again',
#    '.',
#    '@',
#    'SouthwestAir',
#    'saves',
#    'the',
#    'day',
#    '.'],
#   'neutral'],
#  [['@', 'SouthwestAir', 'thanks', '!', '!'], 'neutral'],
#  [['@',
#    'united',
#    'I',
#    "'m",
#    'not',
#    'a',
#    'child',
#    '.',
#    'I',
#    "'m",
#    'someone',
#    'who',
#    'has',
#    'an',
#    'issue',
#    'with',
#    'flying',
#    'and',
#    'prepares',
#    'ahead',
#    'of',
#    'time',
#    'to',
#    'reduce',
#    'the',
#    'distress',
#    'caused',
#    'by',
#    'planes',
#    '.',
#    'You'],
#   'negative'],
#  [['@', 'USAirways', 'i', 'hate', 'you'], 'negative'],
#  [['@',
#    'USAirways',
#    'made',
#    'it',
#    '!',
#    'Just',
#    '!',
#    'Huge',
#    'relief',
#    '-',
#    'thanks',
#    'for',
#    'your',
#    'help',
#    '!'],
#   'positive'],
#  [['@',
#    'united',
#    ',',
#    'maybe',
#    'do',
#    "n't",
#    'play',
#    'the',
#    'video',
#    'about',
#    'how',
#    'your',
#    'flights',
#    'are',
#    'outfitted',
#    'w',
#    'wifi',
#    'on',
#    'the',
#    'flights',
#    'where',
#    'wifi',
#    'is',
#    "n't",
#    'working',
#    '...',
#    '✈️'],
#   'negative'],
#  [['@',
#    'united',
#    'she',
#    "'s",
#    'the',
#    'type',
#    'of',
#    'person',
#    'that',
#    'can',
#    'make',
#    'a',
#    'customers',
#    'day',
#    '!',
#    'I',
#    'fly',
#    '100+',
#    'times',
#    'a',
#    'year',
#    '&',
#    'amp',
#    ';',
#    'she',
#    "'s",
#    'one',
#    'of',
#    'the',
#    'top',
#    'flight',
#    'attendants',
#    'I',
#    "'ve",
#    'had',
#    '!'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'um',
#    '.',
#    'down',
#    'south',
#    'has',
#    'snow',
#    'too',
#    '#',
#    'ATL'],
#   'neutral'],
#  [['@', 'USAirways', 'thank', 'you'], 'neutral'],
#  [['@',
#    'AmericanAir',
#    'Please',
#    'REPLY',
#    '!',
#    'How',
#    'do',
#    'you',
#    'mess',
#    'up',
#    'my',
#    'rebook',
#    'TWICE',
#    '?',
#    '?',
#    '?'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'by',
#    'any',
#    'chance',
#    'do',
#    'u',
#    'offer',
#    'fresh',
#    'guacamole',
#    'on',
#    'your',
#    'flights'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'between',
#    'your',
#    'airline',
#    'and',
#    '@',
#    'united',
#    'I',
#    "'ve",
#    'now',
#    'spent',
#    'three',
#    'extra',
#    'days',
#    'traveling',
#    '(',
#    'DOMESTIC',
#    ')',
#    'and',
#    'spent',
#    'hundreds',
#    'of',
#    'dollars',
#    '...'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'hope',
#    'your',
#    'flyers',
#    'get',
#    'a',
#    'credit',
#    'of',
#    'some',
#    'sort',
#    'for',
#    'all',
#    'the',
#    'delays',
#    'and',
#    'Cancelled',
#    'Flightlations',
#    '#',
#    'shittydeal',
#    '#',
#    'notimpressed'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'The',
#    'problem',
#    'is',
#    'apologies',
#    'do',
#    "n't",
#    'help',
#    '.',
#    'Results',
#    'matter',
#    'and',
#    'it',
#    "'s",
#    'proving',
#    'impossible',
#    'to',
#    'find',
#    'anyone',
#    'who',
#    'is',
#    'interested',
#    'in',
#    'that',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'that',
#    "'s",
#    'absolutely',
#    'horrible',
#    'customer',
#    'service',
#    '.',
#    'The',
#    'person',
#    'supposed',
#    'to',
#    'call',
#    'me',
#    'ca',
#    "n't",
#    'immediately',
#    'call',
#    'back',
#    'when',
#    'disconnected',
#    '?',
#    '?',
#    '?'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'flight',
#    '790',
#    'you',
#    'had',
#    'us',
#    'stuck',
#    'on',
#    'the',
#    'plane',
#    'for',
#    'nearly',
#    '4',
#    'hrs',
#    '.',
#    'Set',
#    'to',
#    'take',
#    'off',
#    'only',
#    'for',
#    'flight',
#    'control',
#    'to',
#    'deny',
#    'us',
#    '.',
#    'THE',
#    'WORST',
#    'SERVICE'],
#   'negative'],
#  [['@',
#    'united',
#    'ok',
#    'thanks',
#    '!',
#    'Where',
#    'are',
#    'you',
#    'counters',
#    'located',
#    '?',
#    'And',
#    'how',
#    'Late',
#    'Flight',
#    'are',
#    'they',
#    'open',
#    '?'],
#   'neutral'],
#  [['@',
#    'united',
#    'Terminal',
#    '1',
#    'gate',
#    'B3',
#    '.',
#    'Flt',
#    '1299',
#    '.',
#    'Then',
#    'take',
#    'her',
#    'to',
#    'Terminal',
#    '5',
#    '.',
#    'Gate',
#    'M13',
#    '.',
#    'Swiss',
#    'Air',
#    'LX009'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'fight',
#    'got',
#    'Cancelled',
#    'Flighted',
#    'can',
#    'u',
#    'help',
#    'me',
#    'rebook',
#    'a',
#    'flight',
#    '?',
#    'Call',
#    'center',
#    'is',
#    'too',
#    'busy',
#    'to',
#    'answer',
#    'calls',
#    'or',
#    'even',
#    'put',
#    'me',
#    'on',
#    'hold',
#    '#',
#    'yuck'],
#   'negative'],
#  [['@',
#    'united',
#    'I',
#    'had',
#    'to',
#    'change',
#    'airports',
#    'to',
#    'actually',
#    'get',
#    'a',
#    'flight',
#    'out',
#    'when',
#    'my',
#    'flight',
#    'from',
#    'FAY',
#    'was',
#    'Cancelled',
#    'Flightled',
#    'twice',
#    '.',
#    '$',
#    '180',
#    'taxi',
#    'ride',
#    'to',
#    'RDU',
#    '--',
#    'reimburse',
#    '?'],
#   'negative'],
#  [['@',
#    'united',
#    'yes',
#    ',',
#    'supposed',
#    'to',
#    'be',
#    'here',
#    'by',
#    '6PM',
#    '.',
#    'I',
#    'have',
#    'a',
#    'Board',
#    'Meeting',
#    'tomorrow',
#    '.',
#    'Fingers',
#    'crossed',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'To',
#    'add',
#    ',',
#    'I',
#    'have',
#    'to',
#    'get',
#    'up',
#    'to',
#    'go',
#    'to',
#    'work',
#    'tomorrow',
#    'am',
#    '.',
#    'I',
#    'do',
#    "n't",
#    'like',
#    'having',
#    'to',
#    'wait',
#    'up',
#    'until',
#    '12',
#    'or',
#    'Late',
#    'Flightr',
#    '.',
#    'CS',
#    'sucks',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    'the',
#    'refund',
#    'team',
#    'is',
#    'far',
#    'from',
#    'customer',
#    'care',
#    'courtesy',
#    'they',
#    'need',
#    'training',
#    'on',
#    'work',
#    'ethics',
#    '.',
#    'So',
#    'it',
#    "'s",
#    'like',
#    'sir',
#    'u',
#    'r',
#    'lying',
#    'how',
#    'can',
#    'I',
#    'help'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'I',
#    'understand',
#    'that',
#    ',',
#    'but',
#    'I',
#    "'m",
#    'not',
#    'even',
#    'being',
#    'put',
#    'on',
#    'hold',
#    '-',
#    'it',
#    'says',
#    '``',
#    'try',
#    'again',
#    'Late',
#    'Flightr',
#    ',',
#    'goodbye',
#    "''",
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'truly',
#    'dissapointed',
#    'when',
#    'our',
#    'flight',
#    'is',
#    'delayed',
#    'and',
#    'going',
#    'to',
#    'miss',
#    'connection',
#    'that',
#    'we',
#    'are',
#    'expected',
#    'to',
#    'rebook',
#    'our',
#    'own',
#    'flight',
#    '?',
#    '?',
#    '?',
#    '?',
#    '?',
#    '?',
#    '?',
#    '?'],
#   'negative'],
#  [['@',
#    'united',
#    'bet',
#    'you',
#    'wont',
#    'honour',
#    'them',
#    ',',
#    'like',
#    'mine',
#    'ey'],
#   'neutral'],
#  [['@',
#    'JetBlue',
#    'When',
#    'I',
#    'got',
#    'your',
#    'alert',
#    ',',
#    'I',
#    'immediately',
#    'started',
#    'looking',
#    'to',
#    'rebook',
#    '.',
#    'But',
#    'we',
#    'only',
#    'had',
#    '11',
#    'minutes',
#    'from',
#    'reFlight',
#    'Booking',
#    'Problems',
#    'to',
#    'catch',
#    'a',
#    'flight',
#    'to',
#    'SRQ',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'wifi',
#    'stays',
#    'connected',
#    'about',
#    'the',
#    'lifetime',
#    'of',
#    'a',
#    'higgs',
#    'boson'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    '-',
#    'holding',
#    'us',
#    'hostage',
#    'for',
#    'about',
#    'an',
#    'hour',
#    'with',
#    'no',
#    'updates',
#    'if',
#    'they',
#    'are',
#    'taking',
#    'us',
#    'to',
#    'NY',
#    'or',
#    'not',
#    '.',
#    'What',
#    "'s",
#    'going',
#    '@',
#    'southwestair'],
#   'negative'],
#  ...]

# %% [markdown]
# Cleaning the Words using WordNetLemmatizer available in NLTK

# %%
stops = set(stopwords.words('english'))
punctuations = list(string.punctuation)
stops.update(punctuations)

# %%
from nltk.corpus import wordnet
def get_simple_pos(tag):
    
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
lemmatizer = WordNetLemmatizer()
def clean_tweets(words):
    output_words = []
    for w in words:
        if w.isalpha():
            if w.lower() not in stops:
                pos = pos_tag([w])
                clean_word = lemmatizer.lemmatize(w, pos = get_simple_pos(pos[0][1]))
                output_words.append(clean_word.lower())
    return output_words

# %%
for i in range(len(tweets_train)):
    tweets_train[i] = (clean_tweets(tweets_train[i][0]), tweets_train[i][1])

# %%
y_train = []
tweets = []
for tweet, sentiment in tweets_train:
    tweets.append(" ".join(tweet))
    y_train.append(sentiment)

# %% [markdown]
# # Using Count Vectorizer to get the X Train

# %%
count_vec = CountVectorizer(max_features=2000) # Tried using n grams but the accuracy was decreasing
x_train_features = count_vec.fit_transform(tweets)

# %% [markdown]
# # Preparing Testing Data

# %%
test_features
# Out:
#                                                    text
# 7540  @SouthwestAir thank you so much completely mad...
# 3175  @VirginAmerica Is flight 0769 out of LGA to DF...
# 6320               @AmericanAir well Done all of you xx
# 6745  @JetBlue @weepysweetmonty i heard youre planni...
# 581   @united, if you mean beyond opaque "maintenanc...
# ...                                                 ...
# 9897  @USAirways Thank you!!! On our way to get her ...
# 3588  @SouthwestAir from groupA to group C. We have ...
# 7218  @AmericanAir Rebooked for tomorrow morning. Ne...
# 2724  @united my son is a passenger on flight 3710 f...
# 6994  @united hey I left my favorite blanket on the ...
#
# [3294 rows x 1 columns]

# %%
testing_data = np.array(test_features['text'])
testing_data
# Out:
# array(['@SouthwestAir thank you so much completely made things right!',
#        '@VirginAmerica Is flight 0769 out of LGA to DFW on time?',
#        '@AmericanAir well Done all of you xx', ...,
#        '@AmericanAir Rebooked for tomorrow morning. Never been here - not sure what I can see before tomorrow morning!',
#        '@united my son is a passenger on flight 3710 from Chicago to Toronto. The plane came within feet of colliding  another plane and is stopped.',
#        '@united hey I left my favorite blanket on the plane bring it back home to me:-('],
#       dtype=object)

# %%
tweets_test = []
for t in testing_data:
    t = clean_tweets(word_tokenize(t))
    tweets_test.append(" ".join(t))

# %%
tweets_test
# Out:
# ['southwestair thank much completely make thing right',
#  'virginamerica flight lga dfw time',
#  'americanair well done xx',
#  'jetblue weepysweetmonty heard youre planning let people fly overhead compartment would',
#  'united mean beyond opaque maintenance issue yes would basic customer service ewr staff ca manage',
#  'jetblue want fly storm right give u choice kid want chance nixchangefees',
#  'southwestair hold hour minute cust service help',
#  'jetblue sure email screenshot link http http',
#  'southwestair min away',
#  'usairways right end sight',
#  'united miss amaze u bank work conference',
#  'southwestair landed hour late flight ind den min late flightr bag cool',
#  'jetblue pretty nice flight credit automatically give flight also wish lounge could sleep',
#  'united appreciate sentiment able get ground still miss connection',
#  'usairways told return call human',
#  'southwestair thanks good air side caution',
#  'jetblue oh yeah great flight mexico wonderful crew thank',
#  'united say would need get supervisor wait supervisor hung',
#  'united stopped fly united yr ago bc aggressive policy carryon bdl listen pssngrs force chk preboard notcomingback',
#  'usairways eyyyy cancelled flightlations flight booking problemss reflight booking problemss get flight tonight tomorrow amp fc upgrade thx',
#  'usairways minute delay take minute wait checked bag really',
#  'americanair give choice rep meelan uk aa contact center escalate flight supervisor book change',
#  'jetblue using jetblue mile',
#  'usairways next plane broken seat row another hour delay mad',
#  'virginamerica website suck donkey dick thought know best',
#  'usairways phl bgm believe happen two week',
#  'united get tsa finally board ua',
#  'americanair like make scene address properly please',
#  'southwestair boarding pass compatible iphone passbook http',
#  'united sure business go else airline travel name kathryn sotelo',
#  'americanair overweight flight sell ticket seat know let call',
#  'united kind cool run bos man sfo http',
#  'jetblue thanks update http',
#  'jetblue get plane wait another hour someone buffaloairport read temp tire',
#  'usairways apology',
#  'jetblue info flight sju jfk already delayed hour',
#  'usairways delayed flight time cancelled flighting angry rude worker provide helpful service',
#  'americanair oh seem reappear lol',
#  'usairways guy need help reservation try call told call late flightr please help',
#  'united think dm would well',
#  'united care thehipmunk link show wrong price site amp responsibility ensure correctness',
#  'united waiver business cancelled flighted due weather extreme circumstance',
#  'americanair paid use paypal online charge system error end call',
#  'jetblue thanks flight leaf arrive airport early wedding vt sept grateful fly btv',
#  'usairways member staff phl give u excellent customer care shame could say past hour',
#  'americanair pls help seriously beyond ridiculous',
#  'americanair mind aa point twitter acct form letter character less',
#  'jetblue ok super helpful thank reach question',
#  'southwestair sent screen shot incident report',
#  'united first lose bag cancelled flight flight home min wait talk somebody poorservice notgoodenough',
#  'jetblue phone rep min transfer ask bad rep ever',
#  'americanair way could put hotel night sleep airport tonight',
#  'jetblue offer service daytona beach new york albany business review http',
#  'americanair trying make online flight booking problems one way barbados wont let say need barbados cc',
#  'americanair unacceptable allow wait hold take number call',
#  'united flight yyc provide free food allow back board broken lightbulb',
#  'united force check rollaboard ua plenty room overhead next seat http',
#  'usairways best gagent long time danny appreciated date kept u irrops super professional',
#  'southwestair sit outside gate min lga move another gate e baking plane flight',
#  'southwestair rebook keep tell reserv number past date morning holding',
#  'united silly fly delta today united club staff attendant surly unhelpful always seem bother pesky folk',
#  'southwestair left something plane land midway last night responsible adult get number call ty',
#  'virginamerica phone number ca find call flight reservation',
#  'americanair barrettkarabis joke mail receipt yet ca mail payment fly hand right',
#  'americanair tired sit delayed computer',
#  'jetblue even citi respond quicker via twitter fail still hold hop one book flight jetblue fail',
#  'jetblue called jb time everytime auto vmsg wait time longer min wait longer min answer',
#  'usairways wo help get luggage back teen try change world dc usairways',
#  'americanair flight veers icy runway dfwairport dfw flight cancelled flighted mon http cowboycerrone figure right',
#  'usairways apology thin even offer hotel voucher strand customer',
#  'united club den east west disgust http',
#  'usairways airline rather poor right slc wait take suppose take hour minute ago',
#  'jetblue ur ask heavy gun know iwoulddoanythingforlove http brandmance lovesongfriday',
#  'americanair willing hold agent helpful keep hang americanairsucks hiremorepoeple',
#  'united bad coffee juice getphilz united terminal sfo airport http',
#  'americanair forecast dfw tu change policy reservation hold wed morning leeway',
#  'united would make day could take flight airline without hiccup end train employee communicate',
#  'americanair try amp disrespectful professional amp flight cancelled flighted get home surgeryhelp',
#  'americanair flight la delayed',
#  'virginamerica dream http http',
#  'americanair like apologize gate agent flight aware zone nine precious gem',
#  'usairways voice concern ca get home month old wait taxi gate hour',
#  'jetblue less concerned delay notify look board flight delayed',
#  'usairways apply ur credit card automatically get companion certificate wait',
#  'southwestair completely let tonight gate agent ambivalence much sad amp',
#  'united lack customer service astounds bad airline history airline train staff',
#  'united get lose kindle mail thanks',
#  'jetblue love flight there always delay unfortunately',
#  'united want let know wonderful rosetta gate agent work flight dan ase let know wasappreciated',
#  'americanair always enjoy time plane dfw',
#  'americanair yesterday phone',
#  'southwestair travel savannah ga airline luv r u go fly savannah pleeeease',
#  'southwestair thank',
#  'united change make hour something take second online thrill loved agent though',
#  'americanair westjet rep wo anything lose never even checked westjet lose',
#  'americanair thnkx bt dont help need go way way get need u charge sux neveragain',
#  'usairways yes every one every flight like need velcro something',
#  'united well sorta r try get aquadilla pr flight go day book ua cancelled flighted flight nj',
#  'americanair hello baggage lose another city anyone help',
#  'usairways would kill give second bad muzak instead constant commercial hold',
#  'jetblue serious attitude fault run tad behind even knew name flight info assured',
#  'lmao jetblue fleet fleek http',
#  'southwestair thing change ticket cancelled flighting current ticket amp buying replacement online',
#  'southwestair happy finally put southwestairlines boarding pas passbook makes life much easy',
#  'united quite enjoyable except stuck runway houston',
#  'southwestair heard save year fuel carry around skymall ripskymall',
#  'jetblue hour delay sit plane still wan na charge beer nah good',
#  'united final destination book united quantas united yet contact auckland unaware case id number',
#  'united bullying workforce get gate agent work team never cool delays flight unitedairlines',
#  'usairways keep call help line keep say busy help amp call back late flightr week',
#  'jetblue tsa jetblue never disappoints',
#  'jetblue baggage crew update staff incompetent answer hour',
#  'southwestair southwest airline cancelled flight flight charleston flight cancelled flightation really weather relate flightd',
#  'united finally get helpful appreciate',
#  'usairways hold hour minute go',
#  'southwestair schedule open end october get columbus day wknd new england point check calendar',
#  'usairways thank',
#  'jetblue book flight jetblue separate old mother bit stupid headache',
#  'usairways americanair beyond ridiculous steer problem delay u neveragain wonder sell',
#  'united advertise flight still website still ca book spent hour united support',
#  'americanair lga already time pull flight qqbmug feel free look many flight reticketed',
#  'united let get direct weather delay sfo leg stop reactive proactive',
#  'southwestair hey follow u dm question',
#  'jetblue love song lt thanks jetblue',
#  'americanair see response',
#  'americanair nothing do enough',
#  'usairways hi fly tomorrow weather look ok problematic',
#  'jetblue suppose change near future',
#  'southwestair next arrive atlanta wait full hour luggage place carousel one hour',
#  'usairways seanvrose sean keep mind call plan hold hour',
#  'jetblue able change even space seat checked online flight tmrw ca seem change seat',
#  'southwestair book flight morning ca wait move country',
#  'united agent las let customer know ca help rebook delayed flight den unfriendlyskies http',
#  'usairways americanair hey guy due horrible customer service issue way get checked bag credit',
#  'jetblue already spent stay hotel last night due guy reschedule flight since cancelled flightation spent almost',
#  'americanair sit plane columbus suppose leave hour ago mechanic ca find tool service shock absorber',
#  'usairways noservice good luck try reach human twice sat hold min neveragain',
#  'united help chicago get gate freezing runway seem like crappy thing',
#  'usairways still wait response',
#  'southwestair fjbfsc need receipt show charge amex keep get sent',
#  'united supervisor stacey take claim number give u',
#  'virginamerica status match week go next week hope flt count towards requirement cust svc help',
#  'americanair andyellwood delk lol sure wake response auto tweet hope make',
#  'united need make change reserve seat bought ticket error amp comp seat',
#  'jetblue heard anyone week nonstop flight baggage customer service',
#  'peak caucasity rt jetblue fleet fleek http',
#  'americanair call morning change name upcoming trip able get please advise',
#  'americanair despite inconvenience situation handle quickly appreciate much',
#  'southwestair almost hour hold need cancelled flight flight get refund airline operating',
#  'usairways seriously keep try seven hour corporate policy usairwaysfail',
#  'americanair raleigh update southern state advisory',
#  'usairways need help ticket dm',
#  'united frozen line flight continue due comfort ok sat plane long flight vegas would',
#  'southwestair tweet several time last week flight info storm always timely tweet back thx',
#  'americanair technical problem frustrate answerthephone res hold ca get thru use credit pay',
#  'united ana ticket holder get use lounge u united book u grumpykim',
#  'usairways thanks let know hour delay hour hold',
#  'americanair usairways need talk ensure statement sent bank get credit charge',
#  'jetblue one picture http',
#  'southwestair possible add companion leg trip',
#  'united stuck houston ca seem get plane destination time perfect fly condition',
#  'usairways really u give scotch rock control drunk would let sister change seat group',
#  'jetblue boston gate',
#  'united sent email customer care tell may break sincerely hope help',
#  'united late flight everyone brave weather passenger wait flight crew really',
#  'united put bag plane seattle flight waiting line talk someone bag status matter',
#  'southwestair best case point http happybirthday',
#  'united contd told ask refund use ticket flight get cancelled flightled ticket use',
#  'united yes know question still case fail',
#  'jetblue fleet fleek http',
#  'jetblue wsj jetblue treat right disabledtraveler thanks hassle flight jamaica',
#  'jetblue plane stuck newburgh wo start weather relate flightd well passenger plane hr',
#  'southwestair vinyl part prize',
#  'americanair come want go home ca miss another day work stuckinmemphis texasisclosed',
#  'usairways delay due refuel control true never want fly us airways',
#  'united upgrd guess kit kat look tasty go near sandwich',
#  'jetblue thanks stbernard take time read page find info supervisor felt insist tho show previous comm',
#  'united well bar set low guy really good apology game change u guy learn',
#  'southwestair follow think dm follow',
#  'usairways hold hr try reschedule flight anyone please help u',
#  'usairways handled found tkt floor drop someone way wheelchair get podium',
#  'usairways make reservation make excuses usairwaysfail',
#  'united zero concept customer service oh connection delayed',
#  'southwestair current cancelled flightlation indianapolis girlfriend strand idea help provide',
#  'americanair bot haha always lie',
#  'united flt ord correct per flight ord cvg charge incorrectly',
#  'united try flight option per weblink non available next day frustrate notgoodenough poorservice',
#  'united hold minute talk one employee ask name id hung face',
#  'americanair one receive text alert automate call anything either literally information happen',
#  'southwestair happen customer service cancelled flightled flight day amp uninformed unapologetic staff nolove cali',
#  'united pushing hour hold priceless http',
#  'southwestair need wheelchair gate sure option',
#  'americanair hour still call back hung automate system americanairlines',
#  'southwestair well get comped multiple bag make day http',
#  'united hell mile expire really look forward accrue enough free flight year',
#  'jetblue would good know month ago cancelled flightled flight leave tomorrow telleveryone jetblue neveragain',
#  'usairways charge take flight lol last time fly',
#  'united would like know possiable checkin online must do schiphol',
#  'jetblue thanks',
#  'americanair itinerary ewr dallas la cancelled flightled flight money find way get ewr',
#  'united free like airline anymore',
#  'jetblue show flight abc oh well live nexttime andthewinneris',
#  'usairways worst ever dca customerservice',
#  'united travel lot get still fave ewr cleveland min layover connect dc best option come',
#  'united schedule flight crew competent person work airline',
#  'usairways another dead end handle aa l amp give fail already vm full lose',
#  'americanair even follow still ca get answer phone worst customer service ever customerservice fail',
#  'jetblue ellahenderson highlight delayed freeconcert',
#  'southwestair swa help hotel industry always book flight day need somewhere swa consistent cancelled',
#  'united highly unprofessional overbook flight seat amp feel rearrange schedule mismanagement',
#  'united sure anything building time promise ceo service gotten bad',
#  'southwestair watch staff check passenger list twice first time forgot look ids brutal',
#  'southwestair thank',
#  'jetblue customer service brutal',
#  'united spending afternoon mia fault lounge inconvenient',
#  'southwestair im pray get home alive',
#  'usairways rebooked tuesday arriving late flight tuesday start class cancelled flightled trip',
#  'usairways u cost get home today reason send receipt reimburse',
#  'united chance wait ord afternoon another flight screw hold',
#  'jetblue brandssayingbae well go',
#  'united relax space drink flight united global first lounge http http',
#  'jetblue disappointed flight back boston pr cancelled flightled rebooked next day delayed one compensation',
#  'americanair necessary confident excellent staff make appropriate report',
#  'americanair flt tomorrow move need move tuesday road wo well flight thanks',
#  'united appreciate get put hold get hung request help big group try delta',
#  'southwestair huge problem someone whose ticket cancelled flighted mid trip dm',
#  'united terrible experience exit row economy zero legroom row book return ca change',
#  'americanair horrendous service ever two plane phil hr captain ca get flight info print wtf',
#  'usairways still cricket customer service',
#  'virginamerica avis rental continue button work website book car tried time phone suck',
#  'united hung customer service wait min hold guess vacation happen website work',
#  'united wonder people hate deal airline ridiculous inflexible policy need phone number resolution',
#  'jetblue update flight would appreciate time thanks',
#  'united yet still left yet ca watch directtv firstworldproblems',
#  'usairways hold min cancelled flight reservation afternoon another way web tell call',
#  'americanair hi guy tell emergency divert heathrow york thanks john',
#  'virginamerica jezziegoldz club virgin bumping new york http',
#  'americanair thanks',
#  'united yes terrible service courrier',
#  'united guy awesome thanks',
#  'united much longer take guitar royal commission',
#  'jetblue ok hope thy bahamas next',
#  'virginamerica husband order three drink via screen never come awesome',
#  'jetblue always',
#  'southwestair childrens rate flight',
#  'virginamerica try offer charge additional new ticket strand thurs time last time',
#  'united delay due customer service people provide flightfail',
#  'southwestair thank take good care people als http alstdi',
#  'americanair cjdjpdx valid response multinational corp whose profit measure billion stop understaffing',
#  'virginamerica airline cancelled flighting flight bos help customer get home virgin say good luck',
#  'americanair travel auh iad via etihad iad dfw via aa able retrieve checked bag iad',
#  'southwestair realize wrong departure date thanks make change easy',
#  'united come shuttle bus lga ewr electrical power outlet new airbus interior whyjeff',
#  'usairways travel around world end year number good',
#  'jetblue every time fly jfk even speed work wait min nogood',
#  'jetblue finally finally',
#  'southwestair many tree die stop try sell u credit card optout http',
#  'united yes land',
#  'southwestair fastest response day hour phone never get hold hour line never get flight booking problems desk',
#  'usairways also employee less helpful check bag two left desk completely',
#  'southwestair checkin lame business really last seat broad shoulder haha',
#  'americanair plane veers runway icy dallas airport http',
#  'southwestair finally thx',
#  'united search mileage ticket bom could find single one saver award see play earn mile ca use',
#  'jetblue sadly app also experience difficulty flight information board keep update',
#  'united annricord great appreciate',
#  'jetblue ca pay buck xd',
#  'americanair usairways meal also u company care customer truly disgraceful',
#  'rt jetblue fleet fleek http',
#  'united offer flight cancelled flighted strand away home work',
#  'usairways please give tara g pat back praise helpful phl member lounge',
#  'usairways also add weather condition terrible expecting inch snow advice',
#  'southwestair fly flight tomorrow boarding position flight overbooked funeral attend',
#  'americanair start sell water admiralsclub',
#  'united flight new york love quality plane united wtf crappy aviation newyork http',
#  'united sorry wrong link bag http thats one meant',
#  'usairways need learn operation sit plane overnight gsp realize mech problem delay flight hour',
#  'virginamerica ceo say southwest amp jetblue strayed low cost model http',
#  'americanair call chairman call emerald today call former customer',
#  'jetblue fleet fleek http way',
#  'americanair see photo scale model amp pn wheel deflator specify chapter amm http',
#  'usairways say call travel agency say cant refund usairways didnt accept',
#  'southwestair get flight denver happy',
#  'jetblue update anything know issue front wheel lock',
#  'virginamerica miss nerdbird san jose',
#  'usairways service philly unacceptable look well yr old shouldnt hard time http',
#  'americanair believe understand flight originally book sunday flight cancelled flighted reschedule today',
#  'americanair disgust chicken entree ever see standard seriously nosedive newamerican http',
#  'usairways ill never fly due emotional amp financial stress cause one staff member error',
#  'americanair hah best flight attendant response happy get screw carrier hahahah pathetic',
#  'southwestair flight cancelled flighted tonight told wo receive travel voucher inconvenience really policy',
#  'jetblue tell need way nyc might choose',
#  'united go round amp round go week',
#  'usairways three hour wait counting wait reservation phone serious',
#  'americanair land miami wait gate someone team help u',
#  'united rebooked hour original flight say handle situation bad would understatement',
#  'americanair good luck dfw even aa',
#  'usairways reflight booking problems event fly attend waiting jetway driver still tarmac',
#  'united would next flight',
#  'usairways thanks take flight board providing update flight minute late flight',
#  'usairways thank call cheapoairchat',
#  'usairways tell man there flights next hr standby nothing options try get sick child firevan',
#  'usairways printer problem cause u sit runway min get together',
#  'usairways charge change flight rip reason hand amp want reschedule flight july',
#  'get phone americanair customer service minute get issue resole guy awesome',
#  'usairways hold hour connect wrong department automate system transfer another min amp counting',
#  'southwestair okay sign',
#  'usairways americanair door close min prior departure min laughter agent',
#  'americanair bad rep jacksonville airport rude totally helpful',
#  'united booked tix month ago cheaper customer service useless',
#  'united hour land atl amp still bag mean clothes makeup unitedairlines nothappy',
#  'united yes course treat customer recourse',
#  'united may true however week matter still unresolved get supervisor manager help',
#  'southwestair well travel photo kindle easy tips guide http http http',
#  'americanair min priority bag arrive late flight even plan delta min bag guarantee anyone',
#  'southwestair hi want see new route plan year newark love fly guy hope',
#  'jetblue flight delayed jfk hour hour hour back hour explanation apology',
#  'southwestair thanks much',
#  'usairways ever lose luggage infant year old customer service never answer phone try night',
#  'virginamerica request window seat confirm window get stuck middle seat good way treat silver',
#  'usairways agent say',
#  'usairways hold minute wait talk someone flight tomorrow another number call',
#  'jetblue awesome bestairlineever',
#  'virginamerica sad learn longer fly sfo gt phl hope return',
#  'americanair watch bag abandon depart gate watched gt min owner return min report',
#  'usairways little help u husband hold hour something take minute complete',
#  'united please arrange someone arrive gate flight chicago either refund first class upgrade',
#  'americanair thank response much appreciate',
#  'jetblue dont enough money parking garage fault im pay',
#  'usairways chance u help family rebook flight cancelled flightled',
#  'usairways hold minute terrible customer service mess reservation http',
#  'americanair ok thanks great night aa team',
#  'jetblue im fly icelandair iceland hour check bag way',
#  'united file claim way call update another way',
#  'united sundays husband travel chicago stuck tarmac amp miss connect flight always',
#  'jetblue well say cancelled flight pa system guess try get plane boston confirm',
#  'usairways way treat woman want someone contact explain make acceptable',
#  'southwestair follow proceed',
#  'omgee jetblue onfleek jetblue many people even know mean lol',
#  'united help get flight tonight houston want stuck till monday bad weather move',
#  'jetblue return foodnetwork sobewff limited carry space tummy next flight try snack',
#  'jetblue work plus could access abc app spent still miss oscars disappointed',
#  'jetblue airways receives new coverage analysts bank america jblu legacy http',
#  'southwestair cancelled flightling flight due winter weather totally understandable would sure nice would answer phone',
#  'americanair heard back today put flight tomorrow arrive home pm meaning take day work',
#  'jetblue kylejudah matter direct principle matter gate checked stroller',
#  'americanair send trust traveler id add reservation tsa pre',
#  'united got zero vouchers hotel cab expect serious mileage credit',
#  'americanair policy change see people hamster rabbit',
#  'virginamerica guy start flight end month guess still road trip feb',
#  'united excite put earlier flight get home woo hoo travel',
#  'jetblue well say flight go cancelled flighted amp change earlier miss chance get tomorrow',
#  'virginamerica heyyyy guyyyys try get hour someone call please',
#  'southwestair flight',
#  'americanair lax amp get phone every flight get bos tmrw apparently unavailable',
#  'united deliver thank make sure arrive doorstep',
#  'united someone airport portland buy ticket picked use late flightr perth australia thanks',
#  'jetblue definitely',
#  'usairways wait hold long wait hold forever never receive confirm place help',
#  'united bwood prefer everyone hear complaint amount airline',
#  'hypocrisy rt united sorry able offer full refund exchange rate hop',
#  'jetblue airways corporation nasdaq jblu reaches new high range streetwise report http',
#  'usairways try check online flight tomorrow tried computer tablet phone get error message device',
#  'americanair enough push crew jfk delay counting',
#  'usairways attendant gate enjoyed watch flight destination take horrible attendant give u',
#  'usairways point need sorry need revers agt pick call maybe make flight today',
#  'southwestair finally get hour set thanks',
#  'usairways absolutely staff amaze',
#  'americanair wow flight crew show min flight catering nice treat customer',
#  'united appalled lack communication awful journey ewr bos hr delay need explain well',
#  'well americanair wo fly rebooked jetblue credit actually work free',
#  'usairways as backwards process use credit flight even try get hold customer relation impossible',
#  'united yes flight rebooked lose trust want get anywhere time',
#  'united parryaftab do thnx',
#  'jetblue luggage flight wait hour bag jetblue poorservice',
#  'jetblue absolutely miss connection cause u miss ferry vieques get u vieques also flight voucher prbound',
#  'americanair lose customer today flight today cancelled flightled find call customer service yesterday',
#  'jetblue flew san francisco fort lauderdale last year fantastic time would like go back',
#  'southwestair bad enough seat assign seat exit seat male flight attendant remove',
#  'united silence tell',
#  'usairways already one person say could anything another say know first person talk say',
#  'southwestair bad air line ever compassion handicapped',
#  'americanair weather logistics hold minute call get desk agent',
#  'southwestair person talk could anything normally available online charge part',
#  'jetblue traveling two kid tomorrow age domestic need birth certificate check airport',
#  'southwestair apologize something words mean nothing actions work eom',
#  'united missed connection due mechanical failure uplink prob lose client mon compensate',
#  'united another f cking delay past hours',
#  'jetblue go australia enjoy land always bucket list flyingitforward',
#  'united u guy change age double book seat even though platinum person none',
#  'usairways crazy spoken human yet well way http',
#  'usairways told call back late flightr',
#  'americanair reservation hold wish hold possible phone issue americanair',
#  'usairways big thanks yvonne anthony chairman desk top tier customer service today outstanding service amp support',
#  'united try standby denver tonight cancelled flight father son trip till next year thx try',
#  'americanair inconvenient convenient word',
#  'americanair usairways manch charlotte fl told could get flight west palm beach nothing earlier',
#  'americanair none lax flight dfw cancelled flightled land fine completely arbitrary',
#  'americanair flight cancelled flightled ca get desk nothing show online reservation',
#  'usairways reserve seat aa flight transfer ord evv',
#  'usairways bag flight clt jfk land last night midnight',
#  'southwestair thank thank thank',
#  'united request upgrade ewr bom flight end may miles copay know upgraded',
#  'southwestair thank give reply year ago direct area learn improvement',
#  'united waiting delayed min might miss room case miss connex',
#  'southwestair look like run day still ca get phone follow dm info',
#  'united brothers baggage lose route panamerican cross country cup championship columbia race sunday please help',
#  'americanair hi aa friend si flight dfw gt gt mke cancelled flighted due weather way help option',
#  'southwestair cool bag take bit longer dont give baggage blue carousel tell come',
#  'americanair aa agent say repeat explain told understand english reply conversation',
#  'jetblue pls find bag need get home frustrate hope bag somewhere leaving jfk luggage',
#  'usairways additional charge golf bag club shoe golf ball piece luggage check',
#  'united hope nicer flight time try thing right sell ticket connetion',
#  'united u kept passenger wait night plane put service leaving everyone strand night inexcusable',
#  'united everytime fly ur airline hate even thanks terrible service flight',
#  'americanair also told agent issue prob k fine get compassion others deal',
#  'united thank one month ago none weird club one busiest airport us',
#  'usairways cancelled flightled need locate baggage',
#  'united would never fly united airlines',
#  'usairways travel infant lap anything need notify',
#  'jetblue thanks make',
#  'americanair bad company ever please fly repeat please fly credit delayed',
#  'americanair flight need b first flight frm mia tpa extremely irritated airport hr',
#  'usairways basically stuck pay hidden fee bumped inferior flight jetblue come usairways merger',
#  'americanair know policy ask little kindness due extenuate circumstance',
#  'united website fuck instead flight yesterday today thanks',
#  'united stars bars iah airlineguys airlinegeeks avgeek http',
#  'southwestair area pic take see album',
#  'usairways love give feedback link fill personal info form guy best',
#  'jetblue rude unhelpful suggest catch flight tomorrow suppose home today work wait',
#  'usairways final count hour minute hold told need log airways website nothing else do',
#  'virginamerica please provide status flight cant imagine time web indicates dude weather dallas',
#  'united coshared flight ana unable check hr prior',
#  'virginamerica done need receipt asap could please help',
#  'united flight delayed min bc miss screw danger miss flight',
#  'usairways also great tweet complainer help need robyn manch useless',
#  'united okay thanks help jt appreciate time',
#  'americanair poor customer service unacceptable also bout surfer front website noloveforsurfers pretend',
#  'southwestair swa send customer survey earn toward flight legit',
#  'united still bag clt airport originally told would',
#  'usairways fam thats suppose fly currently try speak human yr phone sys cut pls hlp',
#  'americanair cancelled flighted last flight shv tonight amp flight tomorrow shv multiple flight shv',
#  'virginamerica ladygaga carrieunderwood julie andrews first lady gaga wow last night carrie meh',
#  'usairways hold hour still know bag wo refund flight weather',
#  'united flight unfortunately isolate flightd incident wait less year',
#  'united literally suck',
#  'southwestair friend boston stuck denver name jane rncahill please contact',
#  'americanair father love work well panam',
#  'united airline sucks customer service sucks courtesy incompetent passenger bet ceo fine though',
#  'jetblue may check child crib free flight tomorrow similar policy infant car seat',
#  'southwestair want thank great effort jamie mckinnie buf true pro major delay own raise',
#  'jetblue gnight checked pos amp supervisor unaware policy suck guide internet v unfriendly',
#  'united aircraft closest gate flight one closest gate go chicago',
#  'americanair thank bad experience ever airline hope embarrass airline pathetic',
#  'southwestair thought guy best airline hold hour',
#  'americanair customer service call refund money',
#  'united enough already poor service old plane ridiculous rout time find new airline status match',
#  'americanair service rep happen yet honestly fed sick notice flight get cancelled flighted',
#  'united confirm seat crisis avert beers wo miss',
#  'united oh united much despise thee',
#  'southwestair start route hawaii canada',
#  'jetblue nhlbruins repping bruins cleveland rock n roll hof amp christmas story house jetbluebruins http',
#  'jetblue june yet',
#  'jetblue appreciate actually respond travel way much tell coffee basic option',
#  'americanair please email willing discus experience amp give another try would like speak directly',
#  'jetblue flight leave boston seattle right flight',
#  'jetblue amybruni wifi flight ca tweet oscar party pic bluecarpet',
#  'united apologize president employee blame heard repeat time',
#  'united email jim compton jeff smisek hopefully pay attention',
#  'united thanks ground crew surprised flight arrive beingsuckontarmacsucks',
#  'americanair think try multiple time status bag yesterday disgust',
#  'united thank wish lady little rock told morning ask',
#  'united throw bus starts management almost million miler company',
#  'southwestair although happy cancelled flighted flight home tomorrow phx atl dca happy easy rebook',
#  'united captain behalf front office welcome never heard laugh hard funnycaptain',
#  'jetblue thx confirm yr team awesome thanks prompt amp helpful response cheers less snow everyone future',
#  'united lot unhappy cold people bridge freeze temp hour give info',
#  'americanair non existent take far hide behind corporate logo provide number tcf useless amateur',
#  'usairways guy need much well communication',
#  'southwestair easy fix let business select actually board board',
#  'southwestair cant look confirmation number moment mobile email longer inbox',
#  'southwestair hold min anyone hv connection sw another airline get chi n columbus ewr',
#  'united space doctors note everything first trip lose first suitcase among pleased united',
#  'usairways ca get back lose time',
#  'united shulemstern raise dispute cc provider hopefully clear',
#  'united get thanks',
#  'americanair ca help seat take way handle high volume call day',
#  'jetblue sent suggestion comment via link provide',
#  'united send another confirmation email',
#  'usairways big problem fll clt get clt fly gso cancelled flightled rent car get pop funeral',
#  'jetblue claimed happy way treat',
#  'americanair think week wait enough time contact lose customer',
#  'united several trial several hour wait phone contact customer care get refund get cold shoulder',
#  'jetblue sorry specify meant ground traffic try get terminal',
#  'united flight chicago houston hour pretzel peanut seriously pass',
#  'united standby connect flight list nudgenudge told four slot open save please',
#  'usairways left something recent flight today contact retrieve please thanks',
#  'jetblue flight tomorrow morning cancelled flighted amp ca seem rebook ca even get seat clear answer cancelled flighted',
#  'united please see flight attendant enough room head bag carry save time',
#  'united ok sent u info via dm appreciate help consideration',
#  'virginamerica flight booking problems section website seem broken chrome might wan na look',
#  'united bag reference id number thanks look',
#  'usairways plane pbi clt knew frozen water also saw plane nyc take gate next door',
#  'united baftz rcvd promo book flight silver status would extend dont flier sent didnt think id need',
#  'jetblue show u sense humor flight etiquette video http',
#  'united total class seat connect flight crew late flight miss connection next plane yet u honor',
#  'jetblue yes say runway ready wait port authority remove snow sight',
#  'united airlines ceo jeff smisek disloyal loyal workers http via huffpostbiz',
#  'united bad flight experience ever never ever fly airline',
#  'southwestair could little accommodate extend flight extra day notahappytraveler',
#  'southwestair call someone monday customer relation disappointed treat customer service',
#  'usairways flight operate flyrepublicair arrives flytpa follow flight reagan national http',
#  'jetblue u want helpful save trip westchester cty jfk plus parking info photo http',
#  'southwestair yes minute tweet able reschedule flight thanks',
#  'americanair come next catch home dca let get another great leg tonight',
#  'usairways americanair leave',
#  'americanair wont allow call husband ticket look like seat take cant even call',
#  'united outbound bag lb bag returning home bag lb logic write machine human help require',
#  'united get chance today fly let see redeem last horrendous trip state',
#  'usairways yep check gmail folder regularly',
#  'usairways flight finally arrive charlotte book luggage thru lga room flight mess',
#  'usairways',
#  'southwestair yes please',
#  'southwestair tried leave monday plane left mine one keep get delayed missed work pay cab',
#  'usairways frustrate still gotten back bag sent ny mystery shame time',
#  'jetblue service get bad bad plane ca fly wait aircraft much planning',
#  'americanair get callback take care thanks',
#  'americanair merger usairways usairwis cluster inefficiency misinformation go do',
#  'united thanks occur guy hour extra get bag due delay hour fail',
#  'southwestair trouble check please add dm',
#  'southwestair baggage woman say blatimore would plane morning ca find wtf',
#  'stahhppp rt jetblue fleet fleek http',
#  'united let u gate',
#  'united disappointed united feed small children amp half hour flight honolulu los angeles appalling esp food waspaid',
#  'americanair kudos ticket agent make passenger check bag big fit overhead',
#  'jetblue check awesome bag flight carry decisions',
#  'united way contact flight work father pas head denver',
#  'usairways consolation bag somewhere else real impediment go different vacation',
#  'united thank',
#  'thank americanair jlhalldc customer relations review concern contact back directly john',
#  'usairways mellani whole team columbia sc absolute superstar incredibly helpful',
#  'americanair cinedrones wish team member would pick phone point let alone courteous helpful',
#  'usairways odds get flight delta actually get orlando today flight',
#  'usairways left son duke hat flight last night say mason back way locate thanks advance',
#  'united rude rude',
#  'usairways far call back',
#  'jetblue thank appreciate',
#  'southwestair respond specialolympics athlete notcool southwest',
#  'americanair still reply email sent february even sent email ask acknowledgment recieved nothing',
#  'jetblue okay anything use contactless emv work internal test training currently apple pay specific',
#  'usairways use even flight early return middle work day inconvenient',
#  'united thank',
#  'americanair narrowly make standby lot snag trip',
#  'usairways able mean private conversation help luggage wo fit overhead',
#  'americanair witness manager name denise yell different customer issue rude',
#  'united submit complaint need compensate long take',
#  'southwestair twitter outstanding customer service thank',
#  'jetblue great smooth flight',
#  'americanair delayed way puerto rico delayed way back new york disgraceful',
#  'americanair would like thank customer service team response cancelled flightled flight offering cont',
#  'jetblue flight boston delayed due weather tampa',
#  'usairways glass wine hit altitude',
#  'united contact stuff bag legally blind mess',
#  'united thanks reach seat hard enough cushion ok short flight btw flight crew great',
#  'americanair cost day vacation get rude woman tell go another country figure get',
#  'southwestair wound vet stuck hv trouble agent help hold answer twitter pls respond',
#  'usairways ground crew dca already late flight arrive evenlate flightr',
#  'jetblue hate internet lol',
#  'southwestair u well define plus one small type item carry requirement small backpack',
#  'usairways best follow please',
#  'united send email bad experience send back generic response yet another reason never fly',
#  'united trick make u look popular twitter bad airline wellplayed jokesonus',
#  'southwestair longer change trip companion online year get message ca do online',
#  'americanair almost day still frozen thanks doll',
#  'americanair yep one camera memory card',
#  'southwestair hold hour chance someone help',
#  'jetblue travel rifle hunt trip pistol large rifle case clear freq ask question',
#  'united book first class curbside delivery hour counting teamusa',
#  'united thanks first time united lounge felt welcome',
#  'united guy gay',
#  'united rebooked one late flight',
#  'usairways lack communication office customer amp yall never update ur system u guy establish mess',
#  'jetblue worst booked email confirm amp never informed cancelled flightlation instructed mail write letter http',
#  'usairways flight carryon plane left gate worst customer service seem anyone concern',
#  'usairways instead mile credit account open request merge account deny',
#  'usairways check get airport thanks',
#  'usairways already try conf via dm',
#  'united suntoshi still like united airline',
#  'americanair reservation line wo let speak representative busy literally disconnect bother',
#  'united free hotel make poor customer service disregard',
#  'usairways glad spend hour try track basic information already available',
#  'southwestair bad customer service earth never fly airline',
#  'usairways really middle initial versus middle name else spending time computer issue',
#  'united four schedule flight reservation literally take one unreal',
#  'americanair guy teach poor customer service part american dream',
#  'usairways understand still able view reservation online',
#  'americanair understood integration take time excuse poor customer service',
#  'southwestair bring back jackson ms miss terribly around airline horrible',
#  'usairways get assistance flight plane land hpn connection atl',
#  'usairways yet flight attendant argue exec plat benefit',
#  'southwestair schedule morning day fact yes sure even flight one cancelled flightled',
#  'jetblue still wait board see give u exit row',
#  'united flight experience r often frustrate chi wpg flight attendant april amaze best',
#  'southwestair sent',
#  'usairways decide wreck vacation lose luggage cancelled flighted flight go maneuver',
#  'united guy name otis ord know customerservice able get bag upgraded sure',
#  'virginamerica luv ur people product thing u charge herbal tea black tea caffeine drinker',
#  'usairways already call option flight reimburse never unreliable business traveler',
#  'united followback dm plz',
#  'usairways travel advis nyc phil pa air post one yet still change flt wo pen',
#  'southwestair horse radish',
#  'southwestair thanks told hour ago plane left try stuck wait hour',
#  'united think left phone flight help',
#  'americanair receive actually thank',
#  'americanair reebooked tomorrow aa arrive still open flight',
#  'southwestair fortunately flight take time',
#  'usairways fa attendant phl pwm tonight fab asset team great night team',
#  'united airlines changing mileageplus program winners losers http http',
#  'americanair lavatory freeze problem nitrogen line low tire inflate equipment malfunction',
#  'jetblue sooo earlier say couldnt fly school trip',
#  'americanair ca choose seat online book priceline smh',
#  'united ticket refund purchase brother fly could use refund credit fly respond',
#  'jetblue thanks',
#  'americanair disappointed flight booking problems process add l fee sit together crowd flight impressed far',
#  'usairways expedia hours friend rebook trip korea usairways cancelled flightled connect flight chicago idiotic',
#  'americanair hat admiral lounge attendant yyz terminal give banana toddler none avail elsewhere',
#  'americanair communication seem issue',
#  'usairways mind wait mind wait plane airport room know food',
#  'united read bio see work never encounter airline disappointed understatement',
#  'southwestair please something speed wifi connection plane might well',
#  'united perfect work thank',
#  'united rapid trip plane ticket idaho california problem would wonderful',
#  'americanair thank',
#  'united fine take',
#  'jetblue help problem easily nice guy rock',
#  'jetblue think rly know goin suppose leave',
#  'usairways hold minute well time call get ridiculous',
#  'southwestair happens power level go foot air',
#  'americanair do do much point trip already',
#  'usairways flight dia ontario tomorrow morning access airport via taxi shuttle',
#  'united alright thank much appreciate',
#  'americanair time one helpful miss work nd school nd manager rem mia told want talk u',
#  'americanair thx nothing get u country back us broken plane come get another one',
#  'jetblue check believe give credit automatically',
#  'jetblue jua jfk ask desk incredibly helpful thanks',
#  'americanair fantastic thanks try tweet photo view',
#  'usairways give http',
#  'usairways checkin phlairport shitshow agent behind counter try send wrong',
#  'united would great',
#  'americanair sure frustrate strand airport fate hand',
#  'jetblue rule checked baggage carry ons slc sjo',
#  'united hate passenger',
#  'usairways stuck florida flight service suck nofood nodrinks nohelp',
#  'usairways plan support applepay board usairways mc would nice still use forget card',
#  'united airbus seat awful recline',
#  'southwestair anyone realize ban peanut flight due allergic person ignores oil amp dust previous flight',
#  'united course need help dming lady gent day solution hope best lax',
#  'americanair dm explain whole story earlier flight',
#  'southwestair auto callback wait hold',
#  'jetblue customer feel like stick airline jet blue travel work past year never see',
#  'jetblue give delayed hour mco jfk every time',
#  'jetblue yes today flight full say gate',
#  'usairways thanks need locate luggage',
#  'jetblue woman lead work gate',
#  'americanair fly competitor today start u end never make mistake americanforlife',
#  'usairways customer service joke first mechanical cancelled flightation weather hold since human pls call',
#  'southwestair sit newark flight cancelled flightled apparent reason told sorry hr wait',
#  'jetblue wonder website issue today trying book flight visa always use reject',
#  'jetblue home guy recover laugh extra day barbados open cuba soon',
#  'united announcement extra baggage find empty bin aisle back baggage seat row agent argue',
#  'southwestair go inconsistent enforce rule prefer randomly take freq flyer obey',
#  'americanair best agent could put flight arrive tomorrow afternoon six hour layover',
#  'united reboot chicago dispatch system need pivotalcf tire sit plane',
#  'usairways weather excuse poor customer service lack info staff fact staff turn',
#  'jetblue many delay north east city',
#  'united chance could look problem earlier',
#  'united time finally get dallas could driven less frustration cheaper',
#  'jetblue flight oahu could best friend vincenzolandino',
#  'americanair upset hometown airline stuck den flt cancelled flightled others get new flt info',
#  'usairways ca stress enough awful agent flight knew ppl delayed flight way min compassion',
#  'virginamerica late flight bag check lose business miss flight apt three people flight exp',
#  'united follow message thanks much help',
#  'united thanks',
#  'usairways flight phoenix deboards passenger go salt lake city ca resolve simple bathroom issue fail',
#  'usairways cancelled flightled flight person line one agent help rebook could hand one well http',
#  'united dm sent',
#  'virginamerica really experience hop w force check small carry nothing empty cabin space board',
#  'united pleasantly surprised find ana make major upgrade transpacific route flight plane service',
#  'southwestair birthday destinationdragons im huge anyway get ticket',
#  'united bad worst reservation policy worst costumer service worst bad bad congrats delta bad',
#  'jetblue ur wed flight really need well schedule almost always delayed',
#  'usairways hold flight dsm dca cancelled flighted know fly',
#  'usairways mobile boarding pas email',
#  'jetblue seriously go http',
#  'united update power outlet tvs yet flying ord',
#  'usairways link broken online baggage locator already try give useful information',
#  'americanair reason flight chicago boarding still seat assignment seriously',
#  'southwestair best airline one well onelove southwest bestairline',
# ...
#  'southwestair winner destinationdragons',
#  'united hour delay nothing say sorry like voucher missing time family family precioustime',
#  'southwestair confirmation number new reservation travel year old please email',
#  'jetblue would storage container like green one acceptable check luggage tote http',
#  'usairways please start offering route triflight location instead charlotte atlanta',
#  'usairways assist marccopely already rebooked agents rude unhelpful discourteous frequentflyers appalled unacceptable',
#  'usairways do',
#  'jetblue well lucky fly jb guess would even squish airline',
#  'usairways customer service record say busy assist hang great touch poorservice gma cbsnews',
#  'usairways need contact asap furious',
#  'usairways stop cancelled flighting flight provide real help customer strandedinnashville',
#  'americanair flight go make connection mex',
#  'usairways thanks',
#  'usairways americanair gma could bad airline experience rude unhelpful get yell jetblue need help',
#  'united try cancelled flight try change award ticket date place thanks send link know fee',
#  'americanair delay communication',
#  'united bag lax like promise thing today mess today',
#  'southwestair rock americanair horror',
#  'usairways strand student try get birmingham clt overnight help well',
#  'united still wait find rep work hard upset wait tomorrow pm get mammoth',
#  'americanair pay hotel car ride miss class pay miss work tell talk someone',
#  'southwestair ever reinstate cancelled flighted flight',
#  'jetblue strand passenger help get another flight',
#  'virginamerica grouping virgin others bos weather expose actual cus serv model never flight booking problems virgin',
#  'jetblue bro',
#  'jetblue let someone black twitter multimedia department',
#  'united airline amp time ever fly airline disgrace listen tweet horrible',
#  'jetblue thank thank finally set jetblue app yay',
#  'usairways last night charlotte nc seriously debate never fly minute tarmac connection leaf',
#  'united boarding attendant take shoe amp sock desk show agent foot gross http',
#  'united customer service experience tweet quality assurance',
#  'southwestair never get notification flight cancelled flighted today correct phone email file happy customer',
#  'americanair gate agent minute let u plane wtw ground crew hope ready cover delay',
#  'united even run gate connect flight customer service let u plane park stranded',
#  'southwestair week valentines day feel luv going hr bwi bag even come w',
#  'united cabin functionality mean take customer satisfaction survey',
#  'americanair snack left purpose team helpful morning desk phone',
#  'southwestair today sporadically change flight departure time amp left two hour late flight uncharacteristic u http',
#  'united left flysfo delayed http',
#  'united sadly wasnt due mother nature investigate incident employee sfo terrible customer experience',
#  'southwestair employee social care team staff listening ctr spot fill area ragandisney',
#  'united help ca take without miss galley cart one find pax seat last hour',
#  'americanair end flight la fourth time standby thanks http',
#  'united get campus visit hour still wear clothes',
#  'americanair understand weather would nice hear apology phone move flight inconvenient day',
#  'united czamkoff profit really give damn pay customer greed',
#  'americanair last year flight delayed cancelled flightled do',
#  'americanair guy really improve service experience site personnel one bad experience',
#  'hour delay shortly southwestair brendanpshannon brendan sorry keep wait air shortly',
#  'united suppose customer enjoy scream toddler problem someone complains',
#  'southwestair accept reservation past august',
#  'united give',
#  'americanair cvgairport get together perfect combination delay cancelled flightlations',
#  'jetblue crew gate',
#  'jetblue magic eight ball never steer wrong',
#  'united really bumped gold status ask pay keep get few mile worth',
#  'jetblue thank much effort',
#  'americanair upgraded class inquired red wine sauvignon blanc amp ca pronounce one could describe',
#  'united start daily flight newark milan malpensa replace instead avgeek',
#  'southwestair last week flew dal lax get u almost hour early thank',
#  'united since ua delayed push meal time mean cater meal first',
#  'thank send detail americanair pretty handy dandy info http lookforwardtoflywithaa',
#  'usairways plane move ice move end runway sit lga one runway open',
#  'americanair suprise new vanity kit set frequent traveller thank aa http',
#  'jetblue hope still bae tatianaking thewayoftheid haa man',
#  'united wont transfer flight ticket accompany yr old active military mom emergency brain surgery wow',
#  'southwestair help reflight booking problems flight cancelled flighted',
#  'usairways trying change flight due nyc travel advisory online system cancelled flighted entire flight hold hr',
#  'americanair help cancelled flightled flight like book another flight hold minute counting',
#  'virginamerica another rep kick butt naelah represent team beautifully thank',
#  'jetblue tux date umosaicmecrazy http',
#  'usairways americanair strand cold texas get sick overbooked flight give seat away gooutofbusiness',
#  'southwestair go go',
#  'usairways day hour hold day charge double flight ca even fix worst service ever',
#  'southwestair sent dm additonal info',
#  'southwestair told customer service customer relation extend expiration date unused travel fund',
#  'jetblue thanks bae',
#  'united deny get plane get chance prove fit rookie read bio',
#  'usairways lose faithful customer',
#  'virginamerica website try check',
#  'usairways force section check carry would packed differently check bag even allow piss',
#  'jetblue fine fly haha come random hemophilia need extra assistance',
#  'americanair united write back say challenge week sure shit',
#  'united wait hour give',
#  'usairways go plan understatement flight change family emergency cancelled flight',
#  'americanair hold service line minute phone agent min call droped',
#  'southwestair longer change trip companion online year get message ca do online',
#  'united fly home event tomorrow push back flight ticket wo get home time',
#  'americanair understand',
#  'southwestair sent dm thanks attentiveness matter',
#  'usairways want connect discus sponsorship opportunity http silicon valley day film festival',
#  'jetblue entire system go really',
#  'americanair get call call seem drop instantly alternate avenue resched support',
#  'americanair hope enjoy winterweather brought warm coat glove maria yup new beanie http',
#  'united disappointed service level staff communication bummer',
#  'southwestair pilot plane flight say still time ground minute ago',
#  'americanair gate agent jan l phoenix least able get young daughter seat near wife thank',
#  'united still wait bag web still ca tell location come ups fedex tell u give minute',
#  'virginamerica man steel fly city though frequency',
#  'southwestair glad finally resolve bad ca get free voucher go mine friend travel next time',
#  'united way impatience part untruthful proper system place',
#  'jetblue thanks get orlando early happiness',
#  'united book award tix thaiairways see conf united flight booking problems get get thai',
#  'usairways empty first class seat flight check would automatically upgraded',
#  'jetblue know actual high club surely something join',
#  'united guideline say bag bit taller guideline gon na problem',
#  'americanair worry love fly guy thanks',
#  'southwestair luv swa employee use always',
#  'united direct messaged hear anything back',
#  'americanair forgot lounge',
#  'americanair tell luggage flight sna dfw flight mke cancelled flightled get rebooked ord',
#  'southwestair ridiculous want charge change flight even multiple seat available flight need',
#  'usairways mean vega allow original flight',
#  'jetblue sit plane jfk wait take door open catering stock delayed could nicer',
#  'united fail last week iah next intl trip delta small ual flight lax book',
#  'southwestair app isnt work take like two hour help',
#  'united flight voucher',
#  'jetblue ooh good one speaking miamore know iadore http loving lovesongfriday',
#  'jetblue wonderful thing',
#  'americanair saw american old colour heathrowairport saturday surprised see',
#  'jetblue need flight ath pdx coordinate airline',
#  'americanair thank response book try aa number us airways number time pick',
#  'southwestair make miss thebachelor right wah',
#  'usairways try merge freq flyer accts keep get error message machine call provide help',
#  'usairways expect wait time speak someone via number',
#  'southwestair entire flight luggage miss dca hour nobody know anything',
#  'united sent long note suggestion thanks get back',
#  'usairways qualify free checked bag apply checkin use companion ticket',
#  'virginamerica happen doom',
#  'usairways merge american negatively affect quality integrity longer fly',
#  'hey united upgraded hour international flight forgive thank',
#  'jetblue major directtv issue yesterday system kept reset crew member',
#  'united freq flyer make sad see cust need assistance treat poorly servicefail',
#  'jetblue thanks help',
#  'southwestair sincere cancelled flighted flight make drive hour get home',
#  'jetblue jetbluecheeps friend bought ticket last night one route cost way help',
#  'jetblue keep go back forth able board great agent savannah',
#  'thanks usairways trip screw ive move meeting dinner im still nyc yet',
#  'southwestair send via dm',
#  'united weekend deal company would say otherwise',
#  'jetblue plane hopefully longer mercy playlist thanks',
#  'americanair marxsterbcow real life response customer service issue seriously keep try call u eh might work',
#  'usairways thank next time',
#  'americanair call system fuck joke',
#  'americanair cancelled flight amp flights hr longer amp layover late flight find reasonably price alternative',
#  'jetblue direct flight bos st lucia antigua',
#  'united customer service crap',
#  'united u guy suck never fly u ur supervisor suck',
#  'southwestair best sit gate wait give information delayed make easy',
#  'americanair told get put another flight would get email still gotten one yet',
#  'yes get disconnect due lack wifi strength americanair mauererpower reach gogo help david',
#  'southwestair open online application fall intern position throughout company apply via http',
#  'jetblue physically impossible make airport flight schedule leave less hour',
#  'united think best first class ever gotten denver lax wonderful',
#  'jetblue sound great thank',
#  'southwestair btw completely unable buy wifi flight use galaxy could zoom scroll touch buy',
#  'jetblue long ago trip take place still get credit apply trueblue book',
#  'united negative done waste time amateur customer service thanks least offering',
#  'usairways bad customer service line call time today able talk real human',
#  'southwestair hope real life scene movie',
#  'united submit customer care form jan still response little longer business day',
#  'jetblue thanks use extra time shopping somebody say duty free',
#  'virginamerica reason delay departure vx jfk afternoon',
#  'united thank',
#  'jetblue course suppose say logan login',
#  'americanair need assistance frustrate ca reach reservation phone try book online amp get fare longer avail msg',
#  'united bad service ever',
#  'southwestair neveryamind paid flight new bag easy business class customer right http',
#  'united seriously wifi flight airline without wifi',
#  'usairways americanair arrive flight schedule depart door close agent',
#  'usairways good understand terminology merger brings new verbiage',
#  'americanair cancelled flighted flight left help find hotel stay slept airport',
#  'americanair fly us air change cancelled flightations lead today big finale unacceptable',
#  'united hence ask customer service phone number speak real person get sort',
#  'usairways u guy suck',
#  'usairways stephenrodrick team need build capacity',
#  'usairways americanair hold hour yesterday speak agent hold phone min let bashing begin',
#  'united thanks offer finally make destination albeit hour late flight',
#  'jetblue austin saw water bottle amp snack desk wait passenger im flight booking problems next flight',
#  'jetblue learn customer service sxm work airport jetblue need supervisor anything',
#  'jetblue think gon na win mayweather pacquiao',
#  'virginamerica mood light reclining seat kickin',
#  'southwestair last night thanks follow',
#  'usairways travel day suck malcome k gate rock guy brand want replicate approach style',
#  'united illiterate magic code make customer service site work http',
#  'southwestair brother amp girlfriend flight cancelled flightled time leave hour late flight drop letter grade school help',
#  'americanair u help rebook passenger via hold hour thanks',
#  'united told u wrong carousel number',
#  'united quick response offering assistance lack follow really service expect',
#  'jetblue thanks jb actually birder love need outside hard trap move',
#  'jetblue say delayed due mechanical issue look something little specific',
#  'united lose belonging honest',
#  'usairways quick let board plane sit runway hour clockwork scareways neverfails',
#  'southwestair love airline much thanks much service great snack amaze everything outstanding thanks',
#  'americanair despite chaos still grateful flight home',
#  'americanair try site amp doesnt allow reason allow board morning try diff airline work trip',
#  'united play hide seek gate ca find minute',
#  'united guys horrible',
#  'americanair oh shiz minute wait first hour barrier unbelievable',
#  'first base already like style jetblue',
#  'americanair flight lie flat seat stl pdx around date march',
#  'jetblue one man baggage office say dunno help',
#  'southwestair pair ticket imaginedragons show atlanta love go destinationdragons',
#  'americanair let seriously unhappycustomer',
#  'southwestair way dm',
#  'southwestair thanks drink ticket hook ca wait first international flight nas pumped',
#  'united u bums u lose biggest bag flight',
#  'southwestair one want commit say plane get cancelled flighted customer relation close patience go',
#  'usairways let us plane please go gate absurd',
#  'americanair done thank much',
#  'southwestair late flightly always late flight please get back old swa',
#  'united try enter email device make email typo way fix amp option log',
#  'united dm sent',
#  'usairways wo give u hotel food least suggestion option make metro city ticket',
#  'usairways hour change flight cancelled flightled',
#  'united michelle ord train staff treat customer refresh pleasure deal',
#  'united fly stl saturday expect ice amp snow start look travel waiver thanks',
#  'americanair aa cancelled flightled flight without courtesy notify u alternative poor',
#  'united going day tomorrow still receive bag flight toronto would love see seriousness',
#  'usairways ability switch flight americanair tell bag',
#  'usairways americanair need move reservation due weather middle part would like change depart airport',
#  'united show tone deaf video year wifi come leave virginamerica ftw',
#  'usairways people line one agent',
#  'united thanks good know',
#  'southwestair five people show yet',
#  'southwestair flight cancelled flightled try get refund hold get flight would depart',
#  'usairways rock hit plane delay never easy day us airways ya never fail let',
#  'americanair wait line hour san antonio barely move amp two agent front amp least behind',
#  'jetblue fly infant time bring canister powder formula carry use plastic formula divider',
#  'jetblue ceo weighs profit flyer chronicleherald registration http',
#  'jetblue left coat flight morning overhead bin reported seat thx ticket',
#  'americanair souljacoy aa go fix utterly embarrass customer service wo even answer dang phone',
#  'southwestair thx customer service rep alex patient help reflight booking problems cancelled flighted flight get u tmrw',
#  'united bad airline sit plane airport hour half wait late flight passenger',
#  'united staff laguardia lagos nigeria unprofessional uncaring helpful ou',
#  ...]

# %%
x_test_features = count_vec.transform(tweets_test)

# %% [markdown]
# # Performing Classification

# %% [markdown]
# # Support Vector Machine

# %%
svc = SVC()
svc.fit(x_train_features, y_train)
# Out:
# SVC()

# %%
y_pred_svm = svc.predict(x_test_features)

# %%
accuracy_svm = accuracy_score(test_labels, y_pred_svm)

# %%
accuracy_svm
# Out:
# 0.7738312082574378

# %%
df = pd.DataFrame(y_pred_svm)
df.to_csv('predictions_svm.csv', index = False, header = False)

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestClassifier()
rf.fit(x_train_features, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf = rf.predict(x_test_features)

# %%
accuracy_rf = accuracy_score(test_labels, y_pred_rf)
accuracy_rf
# Out:
# 0.7544019429265331

# %%
df = pd.DataFrame(y_pred_rf)
df.to_csv('predictions_rf.csv', index = False, header = False)

# %% [markdown]
# # Multinomial Naive Bayes

# %%
mnv = MultinomialNB(alpha = 1)
mnv.fit(x_train_features, y_train)
# Out:
# MultinomialNB(alpha=1)

# %%
y_pred_mnv = mnv.predict(x_test_features)

# %%
accuracy_mnv = accuracy_score(test_labels, y_pred_mnv)
accuracy_mnv
# Out:
# 0.7577413479052824

# %%
df = pd.DataFrame(y_pred_mnv)
df.to_csv('predictions_mnv.csv', index = False, header = False)

# %% [markdown]
# # Descision Tree

# %%
dt = tree.DecisionTreeClassifier()
dt.fit(x_train_features, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt = dt.predict(x_test_features)

# %%
accuracy_dt = accuracy_score(test_labels, y_pred_dt)
accuracy_dt
# Out:
# 0.678809957498482

# %%
df = pd.DataFrame(y_pred_dt)
df.to_csv('predictions_dt.csv', index = False, header = False)
